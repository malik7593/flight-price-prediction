# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver=webdriver.Chrome(r"C:\Users\malik\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=04%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=42426175927'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6724f23e-4ea0-47d0-9b6b-7920168c4abd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="20a3809b-7491-4c32-9a40-e5e8eee5e410")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c27d6d30-d9ff-4a78-8fb0-a16ad0bc0e79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="795a1723-831a-4b58-b5b4-459431cc3732")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="50d3f2a0-20c6-4caf-aca5-4b53bd069943")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ebd0477f-ec34-414f-b701-4b3c093d861e")>,
# ...

# %%
name_titels=[]
for i in titles_tag:
    name_titels.append(i.text)
name_titels
# Out:
# ['12h 10m',
#  '12h 40m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '4h 55m',
#  '5h 30m',
#  '5h 50m',
#  '7h 00m',
#  '8h 55m',
#  '9h 30m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 25m',
#  '3h 10m',
#  '3h 40m',
#  '6h 40m',
#  '15h 35m',
#  '2h 10m',
#  '14h 45m',
#  '17h 30m',
#  '25h 05m',
#  '6h 00m',
#  '7h 30m',
#  '7h 50m',
#  '8h 40m',
#  '10h 00m',
#  '10h 30m',
#  '3h 55m',
#  '4h 30m',
#  '26h 40m',
#  '5h 25m',
#  '7h 50m',
#  '9h 45m',
#  '4h 40m',
#  '9h 55m',
#  '4h 40m',
#  '6h 50m',
#  '8h 45m',
#  '8h 55m',
#  '9h 40m',
# ...

# %%
len(name_titels)
# Out:
# 114

# %%
name_titels[:110]
# Out:
# ['12h 10m',
#  '12h 40m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '4h 55m',
#  '5h 30m',
#  '5h 50m',
#  '7h 00m',
#  '8h 55m',
#  '9h 30m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 25m',
#  '3h 10m',
#  '3h 40m',
#  '6h 40m',
#  '15h 35m',
#  '2h 10m',
#  '14h 45m',
#  '17h 30m',
#  '25h 05m',
#  '6h 00m',
#  '7h 30m',
#  '7h 50m',
#  '8h 40m',
#  '10h 00m',
#  '10h 30m',
#  '3h 55m',
#  '4h 30m',
#  '26h 40m',
#  '5h 25m',
#  '7h 50m',
#  '9h 45m',
#  '4h 40m',
#  '9h 55m',
#  '4h 40m',
#  '6h 50m',
#  '8h 45m',
#  '8h 55m',
#  '9h 40m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b pr']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fd529a45-3c9a-46a9-a8e0-6c16eacf7606")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b2c39d1a-45bd-4630-be42-c256ed4b5d41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4da7511b-328c-4d0b-bc80-7986fa7c4522")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4be36309-6cd0-4d29-b430-046e546a884e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3c32a92c-3e9b-4134-a8f7-ae1bd9714d50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="80240dbe-d4f7-4e1e-a366-d86c2a3ab3ab")>,
# ...

# %%
stime_titels=[]
for i in titles_tag:
    stime_titels.append(i.text)
stime_titels
# Out:
# ['18:35',
#  '18:35',
#  '07:00',
#  '08:00',
#  '02:00',
#  '14:20',
#  '15:00',
#  '19:40',
#  '21:00',
#  '10:20',
#  '16:30',
#  '20:30',
#  '12:20',
#  '10:45',
#  '09:15',
#  '16:30',
#  '06:00',
#  '07:00',
#  '09:30',
#  '06:30',
#  '07:15',
#  '08:00',
#  '08:10',
#  '10:40',
#  '12:00',
#  '12:50',
#  '15:30',
#  '16:55',
#  '17:15',
#  '18:55',
#  '20:00',
#  '23:15',
#  '01:05',
#  '07:00',
#  '07:30',
#  '09:30',
#  '10:20',
#  '14:20',
#  '18:35',
#  '19:00',
#  '21:15',
#  '06:00',
#  '08:45',
#  '08:50',
#  '10:45',
#  '11:40',
#  '17:45',
#  '19:45',
#  '04:45',
#  '15:05',
#  '06:20',
#  '11:20',
#  '19:00',
#  '04:25',
#  '08:40',
#  '05:55',
#  '08:40',
#  '13:50',
#  '07:20',
#  '12:55',
#  '07:25',
#  '06:05',
#  '12:55',
#  '11:55',
#  '13:20',
#  '13:20',
#  '05:30',
#  '10:15',
#  '21:20',
#  '06:00',
#  '12:50',
#  '18:30',
#  '13:30',
#  '13:30',
#  '11:25',
#  '13:30',
#  '11:25',
#  '05:15',
#  '13:40',
#  '13:40',
#  '22:15',
#  '22:15',
#  '20:20',
# ...

# %%
len(stime_titels)
# Out:
# 114

# %%
stime_titels[:110]
# Out:
# ['18:35',
#  '18:35',
#  '07:00',
#  '08:00',
#  '02:00',
#  '14:20',
#  '15:00',
#  '19:40',
#  '21:00',
#  '10:20',
#  '16:30',
#  '20:30',
#  '12:20',
#  '10:45',
#  '09:15',
#  '16:30',
#  '06:00',
#  '07:00',
#  '09:30',
#  '06:30',
#  '07:15',
#  '08:00',
#  '08:10',
#  '10:40',
#  '12:00',
#  '12:50',
#  '15:30',
#  '16:55',
#  '17:15',
#  '18:55',
#  '20:00',
#  '23:15',
#  '01:05',
#  '07:00',
#  '07:30',
#  '09:30',
#  '10:20',
#  '14:20',
#  '18:35',
#  '19:00',
#  '21:15',
#  '06:00',
#  '08:45',
#  '08:50',
#  '10:45',
#  '11:40',
#  '17:45',
#  '19:45',
#  '04:45',
#  '15:05',
#  '06:20',
#  '11:20',
#  '19:00',
#  '04:25',
#  '08:40',
#  '05:55',
#  '08:40',
#  '13:50',
#  '07:20',
#  '12:55',
#  '07:25',
#  '06:05',
#  '12:55',
#  '11:55',
#  '13:20',
#  '13:20',
#  '05:30',
#  '10:15',
#  '21:20',
#  '06:00',
#  '12:50',
#  '18:30',
#  '13:30',
#  '13:30',
#  '11:25',
#  '13:30',
#  '11:25',
#  '05:15',
#  '13:40',
#  '13:40',
#  '22:15',
#  '22:15',
#  '20:20',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="717c7bcf-7368-42ed-8d5f-942981da4031")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8a3885b4-c52b-48e3-965d-92ac8dc7b810")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1a3e9ece-7890-4701-a7f4-daeb45a992db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9847dd87-6b07-4edd-a09e-715c89696315")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="80c0a4d0-6581-4a88-8a98-08f94b3631b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2691b7ed-f624-4c6b-855b-c8b245eec758")>,
# ...

# %%
dtime_titels=[]
for i in titles_tag:
    dtime_titels.append(i.text)
dtime_titels
# Out:
# ['06:45\n+ 1 day',
#  '07:15\n+ 1 day',
#  '09:10',
#  '10:10',
#  '04:15',
#  '16:35',
#  '17:15',
#  '21:55',
#  '23:15',
#  '12:40',
#  '21:25',
#  '02:00\n+ 1 day',
#  '18:10',
#  '17:45',
#  '18:10',
#  '02:00\n+ 1 day',
#  '08:00',
#  '09:05',
#  '11:35',
#  '08:40',
#  '09:25',
#  '10:10',
#  '10:20',
#  '12:50',
#  '14:10',
#  '15:00',
#  '17:40',
#  '19:05',
#  '19:25',
#  '21:05',
#  '22:10',
#  '01:25\n+ 1 day',
#  '03:20',
#  '09:15',
#  '09:45',
#  '11:45',
#  '12:35',
#  '16:35',
#  '20:50',
#  '21:15',
#  '23:30',
#  '08:20',
#  '11:05',
#  '11:10',
#  '13:05',
#  '14:00',
#  '20:05',
#  '22:05',
#  '07:10',
#  '18:15',
#  '10:00',
#  '18:00',
#  '10:35\n+ 1 day',
#  '06:35',
#  '23:25',
#  '23:25',
#  '09:45\n+ 1 day',
#  '19:50',
#  '14:50',
#  '20:45',
#  '16:05',
#  '16:05',
#  '23:25',
#  '15:50',
#  '17:50',
#  '16:00\n+ 1 day',
#  '10:55',
#  '18:05',
#  '07:05\n+ 1 day',
#  '10:40',
#  '22:45',
#  '23:10',
#  '20:20',
#  '22:15',
#  '20:20',
#  '23:10',
# ...

# %%
len(dtime_titels)
# Out:
# 114

# %%
dtime_titels[:110]
# Out:
# ['06:45\n+ 1 day',
#  '07:15\n+ 1 day',
#  '09:10',
#  '10:10',
#  '04:15',
#  '16:35',
#  '17:15',
#  '21:55',
#  '23:15',
#  '12:40',
#  '21:25',
#  '02:00\n+ 1 day',
#  '18:10',
#  '17:45',
#  '18:10',
#  '02:00\n+ 1 day',
#  '08:00',
#  '09:05',
#  '11:35',
#  '08:40',
#  '09:25',
#  '10:10',
#  '10:20',
#  '12:50',
#  '14:10',
#  '15:00',
#  '17:40',
#  '19:05',
#  '19:25',
#  '21:05',
#  '22:10',
#  '01:25\n+ 1 day',
#  '03:20',
#  '09:15',
#  '09:45',
#  '11:45',
#  '12:35',
#  '16:35',
#  '20:50',
#  '21:15',
#  '23:30',
#  '08:20',
#  '11:05',
#  '11:10',
#  '13:05',
#  '14:00',
#  '20:05',
#  '22:05',
#  '07:10',
#  '18:15',
#  '10:00',
#  '18:00',
#  '10:35\n+ 1 day',
#  '06:35',
#  '23:25',
#  '23:25',
#  '09:45\n+ 1 day',
#  '19:50',
#  '14:50',
#  '20:45',
#  '16:05',
#  '16:05',
#  '23:25',
#  '15:50',
#  '17:50',
#  '16:00\n+ 1 day',
#  '10:55',
#  '18:05',
#  '07:05\n+ 1 day',
#  '10:40',
#  '22:45',
#  '23:10',
#  '20:20',
#  '22:15',
#  '20:20',
#  '23:10',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="989d34d1-c966-4394-bae6-e66e3f809e31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2df61795-2746-4082-a971-422f3472a34f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b81fea31-8a7f-4828-ac45-d307dba99bb8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="dd71f37d-6c9c-4850-bedb-e4f1db3011a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9822ab1a-5467-4384-8ee3-c76cd998df89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1eb82e3a-ff0a-4fc8-821b-56ae1903c608")>,
# ...

# %%
price_titels=[]
for i in titles_tag:
    price_titels.append(i.text)
price_titels
# Out:
# ['5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '7,468',
#  '7,468',
#  '7,468',
#  '8,003',
#  '8,003',
#  '8,055',
#  '8,055',
#  '8,055',
#  '8,055',
#  '8,160',
#  '8,160',
#  '8,213',
#  '8,843',
#  '8,843',
#  '8,843',
#  '8,869',
#  '8,892',
#  '8,895',
#  '8,895',
#  '8,895',
#  '8,895',
#  '8,895',
#  '8,895',
#  '9,000',
#  '9,000',
#  '9,000',
#  '9,210',
#  '9,368',
#  '9,368',
# ...

# %%
len(price_titels)
# Out:
# 114

# %%
price_titels[:110]
# Out:
# ['5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '7,468',
#  '7,468',
#  '7,468',
#  '8,003',
#  '8,003',
#  '8,055',
#  '8,055',
#  '8,055',
#  '8,055',
#  '8,160',
#  '8,160',
#  '8,213',
#  '8,843',
#  '8,843',
#  '8,843',
#  '8,869',
#  '8,892',
#  '8,895',
#  '8,895',
#  '8,895',
#  '8,895',
#  '8,895',
#  '8,895',
#  '9,000',
#  '9,000',
#  '9,000',
#  '9,210',
#  '9,368',
#  '9,368',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9339c44f-1017-42d3-8228-3be062ae8c33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d38dee4c-d6c3-407c-bbbe-a42d56162ed8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c3d91286-1258-4edb-8008-d9c22c4560a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1b0c6f76-98d5-4f77-a7c3-0e1b4452725f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="0d3bd120-2f7a-4247-96a6-84ec42009bee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f4b8cb2c-c631-431a-a24b-bda05df5aaa9")>,
# ...

# %%
id_titels=[]
for i in titles_tag:
    id_titels.append(i.text)
id_titels
# Out:
# ['I5-747/334',
#  'I5-747/941',
#  'G8-530',
#  'G8-334',
#  'G8-2501',
#  'G8-336',
#  'G8-392',
#  'G8-346',
#  'G8-330',
#  'G8-338',
#  'G8-717/537',
#  'G8-713/413',
#  'G8-1010/287',
#  'G8-286/2606',
#  'G8-191/287',
#  'G8-717/413',
#  'UK-975',
#  'AI-887',
#  'UK-927',
#  '6E-2054',
#  '6E-5001',
#  'AI-665',
#  '6E-5329',
#  'AI-865',
#  '6E-6202',
#  'UK-993',
#  'UK-933',
#  'UK-941',
#  '6E-2046',
#  'SG-8709',
#  'AI-805',
#  '6E-2519',
#  '6E-171',
#  'SG-8701',
#  'UK-943',
#  '6E-5328',
#  'UK-995',
#  '6E-2176',
#  '6E-5041',
#  'AI-624',
#  '6E-6722',
#  'SG-8157',
#  '6E-6278',
#  'UK-963',
#  '6E-218',
#  'UK-945',
#  'UK-955',
#  'SG-8169',
#  '6E-2081',
#  'AI-636',
#  'SG-3001',
#  'SG-2277/350',
#  'SG-2976/279',
#  'I5-764',
#  'AI-481/632',
#  'AI-435/632',
#  'AI-481/634',
#  '6E-2373/628',
#  '6E-2102/5321',
#  '6E-2338/6031',
#  '6E-7403/5381',
#  '6E-5088/5381',
#  '6E-2338/254',
#  'AI-491/612',
#  'AI-471/644',
#  'UK-627/614',
#  '6E-6231/5315',
# ...

# %%
len(id_titels)
# Out:
# 114

# %%
id_titels[:110]
# Out:
# ['I5-747/334',
#  'I5-747/941',
#  'G8-530',
#  'G8-334',
#  'G8-2501',
#  'G8-336',
#  'G8-392',
#  'G8-346',
#  'G8-330',
#  'G8-338',
#  'G8-717/537',
#  'G8-713/413',
#  'G8-1010/287',
#  'G8-286/2606',
#  'G8-191/287',
#  'G8-717/413',
#  'UK-975',
#  'AI-887',
#  'UK-927',
#  '6E-2054',
#  '6E-5001',
#  'AI-665',
#  '6E-5329',
#  'AI-865',
#  '6E-6202',
#  'UK-993',
#  'UK-933',
#  'UK-941',
#  '6E-2046',
#  'SG-8709',
#  'AI-805',
#  '6E-2519',
#  '6E-171',
#  'SG-8701',
#  'UK-943',
#  '6E-5328',
#  'UK-995',
#  '6E-2176',
#  '6E-5041',
#  'AI-624',
#  '6E-6722',
#  'SG-8157',
#  '6E-6278',
#  'UK-963',
#  '6E-218',
#  'UK-945',
#  'UK-955',
#  'SG-8169',
#  '6E-2081',
#  'AI-636',
#  'SG-3001',
#  'SG-2277/350',
#  'SG-2976/279',
#  'I5-764',
#  'AI-481/632',
#  'AI-435/632',
#  'AI-481/634',
#  '6E-2373/628',
#  '6E-2102/5321',
#  '6E-2338/6031',
#  '6E-7403/5381',
#  '6E-5088/5381',
#  '6E-2338/254',
#  'AI-491/612',
#  'AI-471/644',
#  'UK-627/614',
#  '6E-6231/5315',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b52d2071-a82a-4644-8897-6bb47b488989")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="66af6f8b-f3bd-4965-8ea3-040a6a8bda2f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="87bae93b-79d1-464e-97f8-7f136a4f22ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="0faa6b99-4669-4a06-b625-75fdab55ffec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="71622b77-a4cf-43af-938d-9e1dc267ad3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="42cb75b4-f212-45a2-8524-01d698d2677e")>,
# ...

# %%
flight_titels=[]
for i in titles_tag:
    flight_titels.append(i.text)
flight_titels
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'SpiceJet',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
len(flight_titels)
# Out:
# 114

# %%
flight_titels[:110]
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'SpiceJet',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="47adbcea-9221-4691-aa6f-8beef5bcdc4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ac99947c-a6f9-4f2c-a24d-3a830191174c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fed3c2cc-5f68-47ed-85f1-1df723b18199")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f64b8583-7df3-4eb5-9223-9ddaf97cd53e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="df237711-f27b-42cc-b5dc-099203c53492")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="914a0c4f-9c0d-470d-93c4-3c5dfb057343")>,
# ...

# %%
stops_titels=[]
for i in titles_tag:
    stops_titels.append(i.text)
stops_titels
# Out:
# ['New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
# ...

# %%
len(stops_titels)
# Out:
# 228

# %%
NAME1= []
for i in range(1,len(stops_titels),2):
    NAME1.append(stops_titels[i])
NAME1
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
len(NAME1)
# Out:
# 114

# %%
NAME1[:110]
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
NAME2= []
for i in range(2,len(stops_titels),2):
    NAME2.append(stops_titels[i])
NAME2
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
len(NAME2)
# Out:
# 113

# %%
NAME2[:110]
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=flight_titels[:110]
copy['flight id']=id_titels[:110]
copy['price']=price_titels[:110]
copy['arrival time']=dtime_titels[:110]
copy['departure time']=stime_titels[:110]
copy['hours taken']=name_titels[:110]
copy['starting point']=NAME1[:110]
copy['destination']=NAME2[:110]

# %%
copy
# Out:
#           Name   flight id   price    arrival time departure time hours taken  \
# 0     Air Asia  I5-747/334   5,953  06:45\n+ 1 day          18:35     12h 10m
# 1     Air Asia  I5-747/941   5,953  07:15\n+ 1 day          18:35     12h 40m
# 2     Go First      G8-530   5,954           09:10          07:00      2h 10m
# 3     Go First      G8-334   5,954           10:10          08:00      2h 10m
# 4     Go First     G8-2501   5,954           04:15          02:00      2h 15m
# ..         ...         ...     ...             ...            ...         ...
# 105  Air India  AI-807/604  12,150  10:35\n+ 1 day          17:20     17h 15m
# 106  Air India  AI-502/640  12,150  08:35\n+ 1 day          13:30     19h 05m
# 107  Air India  AI-502/604  12,150  10:35\n+ 1 day          13:30     21h 05m
# 108  Air India  AI-506/640  12,150  08:35\n+ 1 day          09:45     22h 50m
# 109  Air India  AI-506/604  12,150  10:35\n+ 1 day          09:45     24h 50m
#
#     starting point destination
# ...

# %%
copy.to_csv('flight1.csv')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BLR&destinationCountry=IN&flight_depart_date=04%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=403370702641'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6eab2c00-d5c3-4428-8e6b-baf5e6288970")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="42391ac8-f2e5-4a68-8157-b65139c34a96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="862c325d-84df-4064-bb85-54079ee45639")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ce4ac753-10cc-4623-a576-a4d81061572b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a79282a6-d04c-4da1-9687-2faad144511a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9dcc53d4-65fe-4e40-b873-c7420a1584f6")>,
# ...

# %%
name_titels=[]
for i in titles_tag:
    name_titels.append(i.text)
name_titels
# Out:
# ['4h 35m',
#  '5h 15m',
#  '10h 20m',
#  '10h 55m',
#  '2h 35m',
#  '4h 25m',
#  '5h 40m',
#  '5h 50m',
#  '7h 45m',
#  '8h 10m',
#  '9h 10m',
#  '9h 35m',
#  '10h 15m',
#  '10h 40m',
#  '11h 00m',
#  '2h 30m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '3h 00m',
#  '3h 00m',
#  '5h 05m',
#  '5h 05m',
#  '5h 10m',
#  '5h 25m',
#  '6h 25m',
#  '6h 35m',
#  '6h 35m',
#  '7h 15m',
#  '7h 25m',
#  '7h 45m',
#  '7h 45m',
#  '7h 50m',
#  '8h 25m',
#  '8h 45m',
#  '9h 05m',
#  '9h 10m',
#  '9h 50m',
#  '9h 55m',
#  '10h 05m',
#  '11h 05m',
#  '11h 10m',
#  '11h 25m',
#  '22h 40m',
#  '2h 40m',
#  '3h 05m',
#  '8h 15m',
#  '21h 00m',
#  '6h 45m',
#  '7h 00m',
#  '12h 15m',
#  '12h 30m',
#  '14h 05m',
#  '25h 05m',
#  '25h 45m',
#  '24h 55m',
#  '5h 25m',
#  '7h 10m',
#  '4h 45m',
#  '4h 55m',
#  '6h 05m',
# ...

# %%
len(name_titels)
# Out:
# 127

# %%
name_titels[:120]
# Out:
# ['4h 35m',
#  '5h 15m',
#  '10h 20m',
#  '10h 55m',
#  '2h 35m',
#  '4h 25m',
#  '5h 40m',
#  '5h 50m',
#  '7h 45m',
#  '8h 10m',
#  '9h 10m',
#  '9h 35m',
#  '10h 15m',
#  '10h 40m',
#  '11h 00m',
#  '2h 30m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '3h 00m',
#  '3h 00m',
#  '5h 05m',
#  '5h 05m',
#  '5h 10m',
#  '5h 25m',
#  '6h 25m',
#  '6h 35m',
#  '6h 35m',
#  '7h 15m',
#  '7h 25m',
#  '7h 45m',
#  '7h 45m',
#  '7h 50m',
#  '8h 25m',
#  '8h 45m',
#  '9h 05m',
#  '9h 10m',
#  '9h 50m',
#  '9h 55m',
#  '10h 05m',
#  '11h 05m',
#  '11h 10m',
#  '11h 25m',
#  '22h 40m',
#  '2h 40m',
#  '3h 05m',
#  '8h 15m',
#  '21h 00m',
#  '6h 45m',
#  '7h 00m',
#  '12h 15m',
#  '12h 30m',
#  '14h 05m',
#  '25h 05m',
#  '25h 45m',
#  '24h 55m',
#  '5h 25m',
#  '7h 10m',
#  '4h 45m',
#  '4h 55m',
#  '6h 05m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b pr']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2f86e15b-8a22-44e7-b7a4-c2e7ba423a35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8be5bfa8-0153-4400-8b0a-12648beb436a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="90ed8b79-2c56-400a-9b94-1eed74120421")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="7eaac341-a60f-4161-8bcd-ffbb362e9238")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="daf86637-eea7-47d4-8b46-bfbaff2342c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="e1949119-ed05-423f-a93e-9e15ae2954f7")>,
# ...

# %%
stime_titels=[]
for i in titles_tag:
    stime_titels.append(i.text)
stime_titels
# Out:
# ['16:05',
#  '09:25',
#  '04:25',
#  '04:55',
#  '06:05',
#  '10:45',
#  '02:00',
#  '10:20',
#  '12:45',
#  '08:00',
#  '07:00',
#  '15:00',
#  '14:20',
#  '21:00',
#  '09:30',
#  '05:15',
#  '06:10',
#  '21:15',
#  '06:10',
#  '06:15',
#  '09:45',
#  '13:30',
#  '14:15',
#  '16:05',
#  '17:20',
#  '20:10',
#  '02:30',
#  '07:20',
#  '08:20',
#  '09:15',
#  '12:00',
#  '18:20',
#  '22:50',
#  '15:30',
#  '19:50',
#  '06:45',
#  '17:45',
#  '13:50',
#  '07:55',
#  '10:15',
#  '06:45',
#  '13:00',
#  '08:25',
#  '07:25',
#  '08:40',
#  '13:00',
#  '23:05',
#  '14:00',
#  '06:05',
#  '05:15',
#  '23:05',
#  '13:00',
#  '09:40',
#  '21:40',
#  '09:40',
#  '05:30',
#  '19:30',
#  '17:45',
#  '08:00',
#  '18:35',
#  '12:40',
#  '12:00',
#  '07:10',
#  '07:10',
#  '20:35',
#  '09:45',
#  '08:10',
#  '21:10',
#  '07:05',
#  '11:55',
#  '06:00',
#  '16:30',
#  '06:00',
#  '12:50',
#  '11:40',
#  '12:50',
#  '10:20',
#  '11:40',
#  '09:30',
#  '08:50',
#  '10:20',
#  '09:30',
#  '07:30',
# ...

# %%
len(stime_titels)
# Out:
# 127

# %%
stime_titels[:120]
# Out:
# ['16:05',
#  '09:25',
#  '04:25',
#  '04:55',
#  '06:05',
#  '10:45',
#  '02:00',
#  '10:20',
#  '12:45',
#  '08:00',
#  '07:00',
#  '15:00',
#  '14:20',
#  '21:00',
#  '09:30',
#  '05:15',
#  '06:10',
#  '21:15',
#  '06:10',
#  '06:15',
#  '09:45',
#  '13:30',
#  '14:15',
#  '16:05',
#  '17:20',
#  '20:10',
#  '02:30',
#  '07:20',
#  '08:20',
#  '09:15',
#  '12:00',
#  '18:20',
#  '22:50',
#  '15:30',
#  '19:50',
#  '06:45',
#  '17:45',
#  '13:50',
#  '07:55',
#  '10:15',
#  '06:45',
#  '13:00',
#  '08:25',
#  '07:25',
#  '08:40',
#  '13:00',
#  '23:05',
#  '14:00',
#  '06:05',
#  '05:15',
#  '23:05',
#  '13:00',
#  '09:40',
#  '21:40',
#  '09:40',
#  '05:30',
#  '19:30',
#  '17:45',
#  '08:00',
#  '18:35',
#  '12:40',
#  '12:00',
#  '07:10',
#  '07:10',
#  '20:35',
#  '09:45',
#  '08:10',
#  '21:10',
#  '07:05',
#  '11:55',
#  '06:00',
#  '16:30',
#  '06:00',
#  '12:50',
#  '11:40',
#  '12:50',
#  '10:20',
#  '11:40',
#  '09:30',
#  '08:50',
#  '10:20',
#  '09:30',
#  '07:30',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1b14a496-93f6-4760-8334-4db6cbfa8191")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="62377b3c-bec8-4cff-b97b-1c87fb4d0d7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="73249d8c-8cda-4b54-b4c4-d31f2242f8b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="bf1aa942-984d-4c2a-9f27-5762f5954c78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="46dcb8c0-fc32-446d-97d7-20fe5f177187")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4286d4e9-c563-4cd4-8c76-f519b024cce6")>,
# ...

# %%
dtime_titels=[]
for i in titles_tag:
    dtime_titels.append(i.text)
dtime_titels
# Out:
# ['20:40',
#  '14:40',
#  '14:45',
#  '15:50',
#  '08:40',
#  '15:10',
#  '07:40',
#  '16:10',
#  '20:30',
#  '16:10',
#  '16:10',
#  '00:35\n+ 1 day',
#  '00:35\n+ 1 day',
#  '07:40\n+ 1 day',
#  '20:30',
#  '07:45',
#  '08:50',
#  '23:55',
#  '08:55',
#  '09:00',
#  '12:30',
#  '16:15',
#  '17:00',
#  '18:50',
#  '20:05',
#  '22:55',
#  '05:25',
#  '10:15',
#  '11:15',
#  '12:10',
#  '14:55',
#  '21:15',
#  '01:45\n+ 1 day',
#  '18:30',
#  '22:50',
#  '11:50',
#  '22:50',
#  '19:00',
#  '13:20',
#  '16:40',
#  '13:20',
#  '19:35',
#  '15:40',
#  '14:50',
#  '16:25',
#  '20:45',
#  '06:55\n+ 1 day',
#  '22:25',
#  '14:50',
#  '14:20',
#  '08:15\n+ 1 day',
#  '22:50',
#  '19:35',
#  '07:45\n+ 1 day',
#  '20:45',
#  '16:40',
#  '06:55\n+ 1 day',
#  '16:25\n+ 1 day',
#  '10:40',
#  '21:40',
#  '20:55',
#  '09:00\n+ 1 day',
#  '13:55',
#  '14:10',
#  '08:50\n+ 1 day',
#  '22:15',
#  '22:15',
#  '22:15\n+ 1 day',
#  '08:50\n+ 1 day',
#  '12:50\n+ 1 day',
#  '11:25',
#  '23:40',
# ...

# %%
dtime_titels[:120]
# Out:
# ['20:40',
#  '14:40',
#  '14:45',
#  '15:50',
#  '08:40',
#  '15:10',
#  '07:40',
#  '16:10',
#  '20:30',
#  '16:10',
#  '16:10',
#  '00:35\n+ 1 day',
#  '00:35\n+ 1 day',
#  '07:40\n+ 1 day',
#  '20:30',
#  '07:45',
#  '08:50',
#  '23:55',
#  '08:55',
#  '09:00',
#  '12:30',
#  '16:15',
#  '17:00',
#  '18:50',
#  '20:05',
#  '22:55',
#  '05:25',
#  '10:15',
#  '11:15',
#  '12:10',
#  '14:55',
#  '21:15',
#  '01:45\n+ 1 day',
#  '18:30',
#  '22:50',
#  '11:50',
#  '22:50',
#  '19:00',
#  '13:20',
#  '16:40',
#  '13:20',
#  '19:35',
#  '15:40',
#  '14:50',
#  '16:25',
#  '20:45',
#  '06:55\n+ 1 day',
#  '22:25',
#  '14:50',
#  '14:20',
#  '08:15\n+ 1 day',
#  '22:50',
#  '19:35',
#  '07:45\n+ 1 day',
#  '20:45',
#  '16:40',
#  '06:55\n+ 1 day',
#  '16:25\n+ 1 day',
#  '10:40',
#  '21:40',
#  '20:55',
#  '09:00\n+ 1 day',
#  '13:55',
#  '14:10',
#  '08:50\n+ 1 day',
#  '22:15',
#  '22:15',
#  '22:15\n+ 1 day',
#  '08:50\n+ 1 day',
#  '12:50\n+ 1 day',
#  '11:25',
#  '23:40',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="7335b2ec-8c17-437d-a26c-3c2520745b1e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="23ec9604-7f40-4374-8161-d9b6443b5a2c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f586a5b0-8079-4e93-8010-8dc864aa12dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a6cc5d19-4450-4a78-b0f5-e8170339b7e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8534af47-7a5d-4421-84ed-55cd6528394d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fe53ec18-6c55-4be2-98be-d954cd363ffd")>,
# ...

# %%
id_titels=[]
for i in titles_tag:
    id_titels.append(i.text)
id_titels
# Out:
# ['I5-784/1427',
#  'I5-744/820',
#  'I5-764/942',
#  'I5-791/1727',
#  'G8-113',
#  'G8-286',
#  'G8-2501/317',
#  'G8-338/383',
#  'G8-1171/242',
#  'G8-334/383',
#  'G8-530/383',
#  'G8-392/325',
#  'G8-336/325',
#  'G8-330/317',
#  'G8-173/242',
#  'SG-191',
#  '6E-2336',
#  'AI-504',
#  'AI-803',
#  'UK-811',
#  'AI-506',
#  'AI-502',
#  'UK-819',
#  'UK-817',
#  'AI-807',
#  'SG-143',
#  '6E-6233',
#  '6E-772',
#  '6E-2026',
#  '6E-5175',
#  '6E-2188',
#  '6E-654',
#  '6E-2036',
#  '6E-2028',
#  '6E-2082',
#  '6E-164/703',
#  '6E-967/6505',
#  '6E-2373/808',
#  '6E-552/827',
#  '6E-152/6536',
#  '6E-2331/827',
#  '6E-6205/6417',
#  '6E-2769/302',
#  '6E-7403/498',
#  'SG-8185/532',
#  '6E-6205/285',
#  '6E-2478/887',
#  '6E-5014/6803',
#  '6E-5088/498',
#  '6E-198/6754',
#  '6E-2478/413',
#  '6E-6205/6505',
#  '6E-2005/6417',
#  '6E-2056/909',
#  '6E-2005/285',
#  '6E-6231/6536',
#  '6E-2348/887',
#  'SG-8938/532',
#  'I5-740',
#  'I5-747',
#  'I5-798/1518',
#  'SG-8171/3028',
# ...

# %%
id_titels[:120]
# Out:
# ['I5-784/1427',
#  'I5-744/820',
#  'I5-764/942',
#  'I5-791/1727',
#  'G8-113',
#  'G8-286',
#  'G8-2501/317',
#  'G8-338/383',
#  'G8-1171/242',
#  'G8-334/383',
#  'G8-530/383',
#  'G8-392/325',
#  'G8-336/325',
#  'G8-330/317',
#  'G8-173/242',
#  'SG-191',
#  '6E-2336',
#  'AI-504',
#  'AI-803',
#  'UK-811',
#  'AI-506',
#  'AI-502',
#  'UK-819',
#  'UK-817',
#  'AI-807',
#  'SG-143',
#  '6E-6233',
#  '6E-772',
#  '6E-2026',
#  '6E-5175',
#  '6E-2188',
#  '6E-654',
#  '6E-2036',
#  '6E-2028',
#  '6E-2082',
#  '6E-164/703',
#  '6E-967/6505',
#  '6E-2373/808',
#  '6E-552/827',
#  '6E-152/6536',
#  '6E-2331/827',
#  '6E-6205/6417',
#  '6E-2769/302',
#  '6E-7403/498',
#  'SG-8185/532',
#  '6E-6205/285',
#  '6E-2478/887',
#  '6E-5014/6803',
#  '6E-5088/498',
#  '6E-198/6754',
#  '6E-2478/413',
#  '6E-6205/6505',
#  '6E-2005/6417',
#  '6E-2056/909',
#  '6E-2005/285',
#  '6E-6231/6536',
#  '6E-2348/887',
#  'SG-8938/532',
#  'I5-740',
#  'I5-747',
#  'I5-798/1518',
#  'SG-8171/3028',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="37b6e31a-d03a-41d5-8191-0bc4f3b4f670")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2cb41da7-0135-4bdc-bd90-1bb6c8dfd848")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="e00c838a-95d4-404d-8be7-86273c5da062")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b47e338b-abb8-4521-84ec-3b7d1fddf5e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2220e32a-9d30-4724-b27a-7ffcea378822")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="97eb99be-a172-4ed1-8692-26fb2f4410c8")>,
# ...

# %%
flight_titels=[]
for i in titles_tag:
    flight_titels.append(i.text)
flight_titels
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air India',
# ...

# %%
flight_titels[:120]
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air India',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6a420e04-c28b-44fc-b7fe-6e4a9ce1ea6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4dbffc61-d2e6-4339-9ffe-a14ec66dd744")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="7b2bd95e-2528-4a3a-b70c-dfb59a1b6b8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c7d611c1-9826-4c3a-8f90-b6a9d274972a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c39d0ee0-f9e8-4a28-9c0e-f99f01222ddb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="7303e36a-fd47-419f-a6d5-f02a5f31b490")>,
# ...

# %%
stops_titels=[]
for i in titles_tag:
    stops_titels.append(i.text)
stops_titels
# Out:
# ['New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
# ...

# %%
NAME1= []
for i in range(1,len(stops_titels),2):
    NAME1.append(stops_titels[i])
NAME1
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
NAME1[:120]
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
NAME2= []
for i in range(2,len(stops_titels),2):
    NAME2.append(stops_titels[i])
NAME2
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
NAME2[:120]
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d6826450-d178-4fcb-aa2f-f45a3049d891")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1bb3f285-b2bf-4101-96be-9adaa677130e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fd408493-5445-47a2-a184-e26e47c8e70e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3882638a-9f6d-4d20-80a7-2b11fd2a71a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b57d1bd2-aba4-414e-b063-53c2d603715b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d1519425-d969-48d3-a3ac-97c10ac0691e")>,
# ...

# %%
price_titels=[]
for i in titles_tag:
    price_titels.append(i.text)
price_titels
# Out:
# ['7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,426',
#  '7,426',
#  '7,741',
#  '7,741',
#  '9,657',
#  '9,657',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '10,470',
#  '10,549',
#  '10,549',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
# ...

# %%
len(price_titels)
# Out:
# 127

# %%
price_titels[:120]
# Out:
# ['7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,426',
#  '7,426',
#  '7,741',
#  '7,741',
#  '9,657',
#  '9,657',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '10,470',
#  '10,549',
#  '10,549',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
#  '10,680',
# ...

# %%
len(stop_titels)
# Out:
# 104

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=flight_titels[:120]+flight_titels[:110]
copy['flight id']=id_titels[:120]+id_titels[:110]
copy['price']=price_titels[:120]+price_titels[:110]
copy['arrival time']=dtime_titels[:120]+dtime_titels[:110]
copy['departure time']=stime_titels[:120]+stime_titels[:110]
copy['hours taken']=name_titels[:120]+name_titels[:110]
copy['starting point']=NAME1[:120]+NAME1[:110]
copy['destination']=NAME2[:120]+NAME2[:110]

# %%
copy
# Out:
#          Name       flight id   price    arrival time departure time  \
# 0    Air Asia     I5-784/1427   7,423           20:40          16:05
# 1    Air Asia      I5-744/820   7,423           14:40          09:25
# 2    Air Asia      I5-764/942   7,423           14:45          04:25
# 3    Air Asia     I5-791/1727   7,423           15:50          04:55
# 4    Go First          G8-113   7,424           08:40          06:05
# ..        ...             ...     ...             ...            ...
# 225   Vistara  UK-706/654/865  13,339  20:55\n+ 1 day          13:40
# 226   Vistara      UK-715/718  13,809  13:00\n+ 1 day          18:15
# 227   Vistara  UK-706/652/849  13,874  19:15\n+ 1 day          13:40
# 228   Vistara  UK-706/654/849  13,874  19:15\n+ 1 day          13:40
# 229   Vistara  UK-995/843/868  13,935           17:00          10:20
#
#     hours taken starting point destination
# 0        4h 35m      Bangalore   New Delhi
# 1        5h 15m      Bangalore   New Delhi
# ...

# %%
copy.to_csv('flight2.csv')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=M&viewName=normal&flexi=0&noOfSegments=2&origin_0=DEL&destination_0=HYD&originCountry_0=IN&destinationCountry_0=IN&flight_depart_date_0=04%2F11%2F2021&origin_1=HYD&destination_1=DEL&originCountry_1=IN&destinationCountry_1=IN&flight_depart_date_1=05%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1051409040752'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3feef0ea-20db-4474-819f-612d58cd87dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="004c0a04-cb3f-4f38-91d8-b169cf16f809")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="19f78ff4-b107-414b-b576-2164a5df21f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d2980e9c-fcb2-4509-8e51-8837e1bda6ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="99996865-6037-4b1f-93bb-275a90b790c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="0473d143-a16d-4b39-b7e8-565909737d81")>,
# ...

# %%
name_titels=[]
for i in titles_tag:
    name_titels.append(i.text)
name_titels
# Out:
# ['6h 35m',
#  '7h 35m',
#  '12h 00m',
#  '13h 55m',
#  '13h 55m',
#  '14h 10m',
#  '2h 10m',
#  '2h 15m',
#  '12h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 25m',
#  '4h 20m',
#  '5h 30m',
#  '6h 15m',
#  '6h 20m',
#  '6h 45m',
#  '7h 10m',
#  '7h 45m',
#  '8h 20m',
#  '9h 30m',
#  '10h 00m',
#  '10h 15m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '6h 35m',
#  '7h 35m',
#  '12h 00m',
#  '13h 55m',
#  '13h 55m',
#  '14h 10m',
#  '4h 20m',
#  '5h 30m',
#  '6h 15m',
#  '6h 20m',
#  '6h 45m',
#  '7h 10m',
#  '7h 45m',
#  '8h 20m',
#  '9h 30m',
#  '10h 00m',
#  '10h 15m',
#  '2h 05m',
#  '11h 20m',
#  '11h 20m',
#  '2h 10m',
#  '2h 15m',
#  '17h 00m',
#  '8h 25m',
#  '17h 00m',
#  '8h 25m',
#  '14h 05m',
#  '14h 55m',
#  '16h 20m',
#  '19h 00m',
#  '20h 10m',
#  '21h 30m',
#  '22h 20m',
# ...

# %%
len(name_titels)
# Out:
# 248

# %%
name_titels[:245]
# Out:
# ['6h 35m',
#  '7h 35m',
#  '12h 00m',
#  '13h 55m',
#  '13h 55m',
#  '14h 10m',
#  '2h 10m',
#  '2h 15m',
#  '12h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 25m',
#  '4h 20m',
#  '5h 30m',
#  '6h 15m',
#  '6h 20m',
#  '6h 45m',
#  '7h 10m',
#  '7h 45m',
#  '8h 20m',
#  '9h 30m',
#  '10h 00m',
#  '10h 15m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 10m',
#  '2h 15m',
#  '6h 35m',
#  '7h 35m',
#  '12h 00m',
#  '13h 55m',
#  '13h 55m',
#  '14h 10m',
#  '4h 20m',
#  '5h 30m',
#  '6h 15m',
#  '6h 20m',
#  '6h 45m',
#  '7h 10m',
#  '7h 45m',
#  '8h 20m',
#  '9h 30m',
#  '10h 00m',
#  '10h 15m',
#  '2h 05m',
#  '11h 20m',
#  '11h 20m',
#  '2h 10m',
#  '2h 15m',
#  '17h 00m',
#  '8h 25m',
#  '17h 00m',
#  '8h 25m',
#  '14h 05m',
#  '14h 55m',
#  '16h 20m',
#  '19h 00m',
#  '20h 10m',
#  '21h 30m',
#  '22h 20m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9d94ac4f-557e-4f06-8026-1c703a1b15b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="7e2b1688-bb48-47c2-a441-a6c4c82ba577")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1289ba1f-893f-463a-8509-54f8cb2e8e17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="70fab1d1-a8db-498a-90e0-3c04f3ac0340")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ed122b37-c295-4f6f-9be8-2c272b245b9c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="5922d5f4-4fab-42f3-ab0e-0403fbbf1aca")>,
# ...

# %%
name_titels1=[]
for i in titles_tag:
    name_titels1.append(i.text)
name_titels1
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
len(name_titels1)
# Out:
# 248

# %%
name_titels1[:245]
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c3979b9c-351b-40e6-8d49-4912a3c3d90a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9cb50476-18e1-4b43-8203-5d0a5bf1e54b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3d8bb38d-4ba7-4f95-88dc-39d69cc83151")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="46546a9f-3077-4534-87b0-49319380001c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f763c023-5835-494a-8663-d9fe28a17ba9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="25714ca0-ed84-400a-8a0e-e795b9dd1916")>,
# ...

# %%
sname_titels2=[]
for i in titles_tag:
    sname_titels2.append(i.text)
sname_titels2
# Out:
# ['19:15',
#  '15:35',
#  '06:35\n+ 1 day',
#  '19:15',
#  '06:45\n+ 1 day',
#  '08:45\n+ 1 day',
#  '09:30',
#  '21:50',
#  '22:50',
#  '19:05',
#  '11:55',
#  '01:15\n+ 1 day',
#  '09:00',
#  '10:10',
#  '11:55',
#  '15:15',
#  '20:00',
#  '09:25',
#  '10:30',
#  '21:50',
#  '22:55',
#  '23:35',
#  '11:20',
#  '11:00',
#  '17:35',
#  '21:20',
#  '19:40',
#  '12:40',
#  '17:00',
#  '21:20',
#  '16:15',
#  '17:00',
#  '17:35',
#  '01:15\n+ 1 day',
#  '09:00',
#  '10:10',
#  '11:55',
#  '15:15',
#  '20:00',
#  '21:50',
#  '09:30',
#  '21:50',
#  '19:15',
#  '15:35',
#  '06:35\n+ 1 day',
#  '19:15',
#  '06:45\n+ 1 day',
#  '08:45\n+ 1 day',
#  '11:20',
#  '11:00',
#  '17:35',
#  '21:20',
#  '19:40',
#  '12:40',
#  '17:00',
#  '21:20',
#  '16:15',
#  '17:00',
#  '17:35',
#  '19:05',
#  '00:10\n+ 1 day',
#  '00:10\n+ 1 day',
#  '09:30',
#  '21:50',
#  '00:10\n+ 1 day',
#  '15:35',
#  '00:10\n+ 1 day',
#  '15:35',
#  '07:50\n+ 1 day',
#  '07:50\n+ 1 day',
#  '07:50\n+ 1 day',
# ...

# %%
len(sname_titels2)
# Out:
# 248

# %%
sname_titels2[:245]
# Out:
# ['19:15',
#  '15:35',
#  '06:35\n+ 1 day',
#  '19:15',
#  '06:45\n+ 1 day',
#  '08:45\n+ 1 day',
#  '09:30',
#  '21:50',
#  '22:50',
#  '19:05',
#  '11:55',
#  '01:15\n+ 1 day',
#  '09:00',
#  '10:10',
#  '11:55',
#  '15:15',
#  '20:00',
#  '09:25',
#  '10:30',
#  '21:50',
#  '22:55',
#  '23:35',
#  '11:20',
#  '11:00',
#  '17:35',
#  '21:20',
#  '19:40',
#  '12:40',
#  '17:00',
#  '21:20',
#  '16:15',
#  '17:00',
#  '17:35',
#  '01:15\n+ 1 day',
#  '09:00',
#  '10:10',
#  '11:55',
#  '15:15',
#  '20:00',
#  '21:50',
#  '09:30',
#  '21:50',
#  '19:15',
#  '15:35',
#  '06:35\n+ 1 day',
#  '19:15',
#  '06:45\n+ 1 day',
#  '08:45\n+ 1 day',
#  '11:20',
#  '11:00',
#  '17:35',
#  '21:20',
#  '19:40',
#  '12:40',
#  '17:00',
#  '21:20',
#  '16:15',
#  '17:00',
#  '17:35',
#  '19:05',
#  '00:10\n+ 1 day',
#  '00:10\n+ 1 day',
#  '09:30',
#  '21:50',
#  '00:10\n+ 1 day',
#  '15:35',
#  '00:10\n+ 1 day',
#  '15:35',
#  '07:50\n+ 1 day',
#  '07:50\n+ 1 day',
#  '07:50\n+ 1 day',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b pr']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="7926cc8b-36f7-42b1-8800-2679d6b4b2f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="92c11b81-9390-4f16-8d64-90aed30f4b22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8b5c8dc4-c432-4e6e-80d4-9d5813939aad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b6923100-3dc6-42d3-ae9c-a76af4a618a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3e4eff9e-e968-4116-b1ad-304ae5eacd84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="380ef1c7-4c1b-411e-8a90-c5e35fc34458")>,
# ...

# %%
dname_titels2=[]
for i in titles_tag:
    dname_titels2.append(i.text)
dname_titels2
# Out:
# ['12:40',
#  '08:00',
#  '18:35',
#  '05:20',
#  '16:50',
#  '18:35',
#  '07:20',
#  '19:35',
#  '10:45',
#  '17:00',
#  '09:45',
#  '23:05',
#  '06:45',
#  '07:55',
#  '09:40',
#  '13:00',
#  '17:45',
#  '07:05',
#  '08:10',
#  '19:30',
#  '20:35',
#  '21:10',
#  '07:00',
#  '05:30',
#  '11:20',
#  '15:00',
#  '12:55',
#  '05:30',
#  '09:15',
#  '13:00',
#  '06:45',
#  '07:00',
#  '07:20',
#  '23:05',
#  '06:45',
#  '07:55',
#  '09:40',
#  '13:00',
#  '17:45',
#  '19:30',
#  '07:20',
#  '19:35',
#  '12:40',
#  '08:00',
#  '18:35',
#  '05:20',
#  '16:50',
#  '18:35',
#  '07:00',
#  '05:30',
#  '11:20',
#  '15:00',
#  '12:55',
#  '05:30',
#  '09:15',
#  '13:00',
#  '06:45',
#  '07:00',
#  '07:20',
#  '17:00',
#  '12:50',
#  '12:50',
#  '07:20',
#  '19:35',
#  '07:10',
#  '07:10',
#  '07:10',
#  '07:10',
#  '17:45',
#  '16:55',
#  '15:30',
#  '12:50',
#  '11:40',
#  '10:20',
#  '09:30',
#  '08:50',
#  '07:30',
#  '06:00',
#  '16:45',
#  '13:30',
#  '09:45',
#  '06:10',
#  '21:15',
# ...

# %%
len(dname_titels2)
# Out:
# 248

# %%
dname_titels2[:245]
# Out:
# ['12:40',
#  '08:00',
#  '18:35',
#  '05:20',
#  '16:50',
#  '18:35',
#  '07:20',
#  '19:35',
#  '10:45',
#  '17:00',
#  '09:45',
#  '23:05',
#  '06:45',
#  '07:55',
#  '09:40',
#  '13:00',
#  '17:45',
#  '07:05',
#  '08:10',
#  '19:30',
#  '20:35',
#  '21:10',
#  '07:00',
#  '05:30',
#  '11:20',
#  '15:00',
#  '12:55',
#  '05:30',
#  '09:15',
#  '13:00',
#  '06:45',
#  '07:00',
#  '07:20',
#  '23:05',
#  '06:45',
#  '07:55',
#  '09:40',
#  '13:00',
#  '17:45',
#  '19:30',
#  '07:20',
#  '19:35',
#  '12:40',
#  '08:00',
#  '18:35',
#  '05:20',
#  '16:50',
#  '18:35',
#  '07:00',
#  '05:30',
#  '11:20',
#  '15:00',
#  '12:55',
#  '05:30',
#  '09:15',
#  '13:00',
#  '06:45',
#  '07:00',
#  '07:20',
#  '17:00',
#  '12:50',
#  '12:50',
#  '07:20',
#  '19:35',
#  '07:10',
#  '07:10',
#  '07:10',
#  '07:10',
#  '17:45',
#  '16:55',
#  '15:30',
#  '12:50',
#  '11:40',
#  '10:20',
#  '09:30',
#  '08:50',
#  '07:30',
#  '06:00',
#  '16:45',
#  '13:30',
#  '09:45',
#  '06:10',
#  '21:15',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="de259ef0-6293-4f56-8a08-fd5681572be9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="134e4a04-e024-473c-be1c-bae0b17cf6a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ec17925a-19b1-48a9-a333-7f815fb94cf1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a4907d4d-c842-4ecb-8ae7-28d7674c2c10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8e370d3c-31d7-4a0e-81d6-fa8e4284c095")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9aec677d-f561-4d70-9974-677739047789")>,
# ...

# %%
price_titels2=[]
for i in titles_tag:
    price_titels2.append(i.text)
price_titels2
# Out:
# ['5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,401',
#  '6,401',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '7,013',
#  '8,112',
#  '8,636',
#  '9,102',
#  '9,102',
#  '9,840',
#  '10,260',
#  '10,366',
#  '10,786',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,218',
#  '11,310',
#  '11,310',
# ...

# %%
len(price_titels2)
# Out:
# 246

# %%
price_titels2[:245]
# Out:
# ['5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,401',
#  '6,401',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,479',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '7,013',
#  '8,112',
#  '8,636',
#  '9,102',
#  '9,102',
#  '9,840',
#  '10,260',
#  '10,366',
#  '10,786',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,048',
#  '11,218',
#  '11,310',
#  '11,310',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c23b210b-3673-4e86-bc2f-0ded80f469fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="45aae260-b6bc-4ba2-969b-2184e2548f5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="0981d15e-652c-4d77-be6b-2fa5ad6feb06")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1080cf2e-ed31-43cc-a23b-d30ed52ed33a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="7037c3d3-b969-4ed6-8f51-2005781c0674")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f5e86272-6bc3-4109-8c5f-590bf136b72a")>,
# ...

# %%
id_titels2=[]
for i in titles_tag:
    id_titels2.append(i.text)
id_titels2
# Out:
# ['I5-798/1518',
#  'I5-740/1983',
#  'I5-747/410',
#  'I5-779/1518',
#  'I5-550/510',
#  'I5-747/1576',
#  'G8-423',
#  'G8-422',
#  'G8-286/572',
#  'SG-161',
#  'AI-542',
#  '6E-2478',
#  '6E-2331',
#  '6E-552',
#  '6E-2005',
#  '6E-6205',
#  '6E-967',
#  'UK-829',
#  'AI-560',
#  '6E-2348',
#  'UK-871',
#  'AI-839',
#  '6E-2076/501',
#  '6E-6231/7272',
#  '6E-2355/6308',
#  '6E-2023/278',
#  '6E-2338/471',
#  '6E-6231/511',
#  '6E-2038/473',
#  '6E-546/278',
#  '6E-164/7122',
#  '6E-2076/473',
#  '6E-2102/6308',
#  '6E-2478',
#  '6E-2331',
#  '6E-552',
#  '6E-2005',
#  '6E-6205',
#  '6E-967',
#  '6E-2348',
#  'G8-423',
#  'G8-422',
#  'I5-798/1518',
#  'I5-740/1983',
#  'I5-747/410',
#  'I5-779/1518',
#  'I5-550/510',
#  'I5-747/1576',
#  '6E-2076/501',
#  '6E-6231/7272',
#  '6E-2355/6308',
#  '6E-2023/278',
#  '6E-2338/471',
#  '6E-6231/511',
#  '6E-2038/473',
#  '6E-546/278',
#  '6E-164/7122',
#  '6E-2076/473',
#  '6E-2102/6308',
#  'SG-161',
#  'I5-792/1541',
#  'I5-792/1541',
# ...

# %%
len(id_titels2)
# Out:
# 248

# %%
id_titels2[:245]
# Out:
# ['I5-798/1518',
#  'I5-740/1983',
#  'I5-747/410',
#  'I5-779/1518',
#  'I5-550/510',
#  'I5-747/1576',
#  'G8-423',
#  'G8-422',
#  'G8-286/572',
#  'SG-161',
#  'AI-542',
#  '6E-2478',
#  '6E-2331',
#  '6E-552',
#  '6E-2005',
#  '6E-6205',
#  '6E-967',
#  'UK-829',
#  'AI-560',
#  '6E-2348',
#  'UK-871',
#  'AI-839',
#  '6E-2076/501',
#  '6E-6231/7272',
#  '6E-2355/6308',
#  '6E-2023/278',
#  '6E-2338/471',
#  '6E-6231/511',
#  '6E-2038/473',
#  '6E-546/278',
#  '6E-164/7122',
#  '6E-2076/473',
#  '6E-2102/6308',
#  '6E-2478',
#  '6E-2331',
#  '6E-552',
#  '6E-2005',
#  '6E-6205',
#  '6E-967',
#  '6E-2348',
#  'G8-423',
#  'G8-422',
#  'I5-798/1518',
#  'I5-740/1983',
#  'I5-747/410',
#  'I5-779/1518',
#  'I5-550/510',
#  'I5-747/1576',
#  '6E-2076/501',
#  '6E-6231/7272',
#  '6E-2355/6308',
#  '6E-2023/278',
#  '6E-2338/471',
#  '6E-6231/511',
#  '6E-2038/473',
#  '6E-546/278',
#  '6E-164/7122',
#  '6E-2076/473',
#  '6E-2102/6308',
#  'SG-161',
#  'I5-792/1541',
#  'I5-792/1541',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9cb24f60-e8bb-450c-a0e2-0fddefc7b2ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b46876cc-7446-4e56-9eb2-ad8d688dc955")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="18ae5e61-faec-45c5-aada-04b6c60f02a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2bbd332b-ce18-4283-8f10-6c81005b63c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="47ee7231-3ea9-42f5-bf97-703c157af090")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fdf9231b-704b-479c-8c32-ec97b6d56895")>,
# ...

# %%
spoint_titels2=[]
for i in titles_tag:
    spoint_titels2.append(i.text)
spoint_titels2
# Out:
# ['New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
# ...

# %%
NAME1= []
for i in range(1,len(spoint_titels2),2):
    NAME1.append(spoint_titels2[i])
NAME1
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
len(NAME1)
# Out:
# 248

# %%
NAME1[:245]
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
NAME2= []
for i in range(2,len(spoint_titels2),2):
    NAME2.append(spoint_titels2[i])
NAME2
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
len(NAME2)
# Out:
# 247

# %%
NAME2[:245]
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=flight_titels[:120]+flight_titels[:110]
copy['flight id']=id_titels[:120]+id_titels[:110]
copy['price']=price_titels[:120]+price_titels[:110]
copy['arrival time']=dtime_titels[:120]+dtime_titels[:110]
copy['departure time']=stime_titels[:120]+stime_titels[:110]
copy['hours taken']=name_titels[:120]+name_titels[:110]
copy['starting point']=NAME1[:120]+NAME1[:110]
copy['destination']=NAME2[:120]+NAME2[:110]

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels1[:245]+flight_titels[:120]+flight_titels[:110]
copy['flight id']=id_titels2[:245]+id_titels[:120]+id_titels[:110]
copy['price']=price_titels2[:245]+price_titels[:120]+price_titels[:110]
copy['arrival time']=sname_titels2[:245]+dtime_titels[:120]+dtime_titels[:110]
copy['departure time']=dname_titels2[:245]+stime_titels[:120]+stime_titels[:110]
copy['hours taken']=name_titels[:245]+name_titels[:120]+name_titels[:110]
copy['starting point']=NAME2[:245]+NAME1[:120]+NAME1[:110]
copy['destination']=NAME1[:245]+NAME2[:120]+NAME2[:110]

# %%
copy
# Out:
#          Name       flight id   price    arrival time departure time  \
# 0    Air Asia     I5-798/1518   5,953           19:15          12:40
# 1    Air Asia     I5-740/1983   5,953           15:35          08:00
# 2    Air Asia      I5-747/410   5,953  06:35\n+ 1 day          18:35
# 3    Air Asia     I5-779/1518   5,953           19:15          05:20
# 4    Air Asia      I5-550/510   5,953  06:45\n+ 1 day          16:50
# ..        ...             ...     ...             ...            ...
# 470   Vistara  UK-706/654/865  13,339  20:55\n+ 1 day          13:40
# 471   Vistara      UK-715/718  13,809  13:00\n+ 1 day          18:15
# 472   Vistara  UK-706/652/849  13,874  19:15\n+ 1 day          13:40
# 473   Vistara  UK-706/654/849  13,874  19:15\n+ 1 day          13:40
# 474   Vistara  UK-995/843/868  13,935           17:00          10:20
#
#     hours taken starting point destination
# 0        6h 35m      New Delhi   Hyderabad
# 1        7h 35m      New Delhi   Hyderabad
# ...

# %%
copy.to_csv('flight9.csv')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=M&viewName=normal&flexi=0&noOfSegments=2&origin_0=BOM&destination_0=HYD&originCountry_0=IN&destinationCountry_0=IN&flight_depart_date_0=04%2F11%2F2021&origin_1=HYD&destination_1=BOM&originCountry_1=IN&destinationCountry_1=IN&flight_depart_date_1=04%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1400495125497'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2c22b2b8-7c4c-4c75-a06d-26c329bc568e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1ce1cebc-de53-4ffe-a95c-e4b08ce64440")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="dc54e3ac-9b8b-4669-b950-5158095d1800")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="95ce8e34-ce39-4142-aac2-a802a8ebd2f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d4fe300e-fdbd-4f33-8478-8bb8991d8d80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="87c589aa-9a3a-4687-9c12-5fb982cf7c3d")>,
# ...

# %%
name_titels=[]
for i in titles_tag:
    name_titels.append(i.text)
name_titels
# Out:
# ['8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 20m',
#  '1h 20m',
#  '1h 20m',
#  '1h 20m',
#  '1h 30m',
#  '1h 20m',
#  '1h 20m',
#  '8h 10m',
#  '15h 35m',
#  '16h 30m',
#  '28h 35m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '24h 50m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '7h 45m',
#  '5h 10m',
#  '8h 05m',
#  '19h 10m',
#  '5h 40m',
#  '7h 10m',
#  '8h 15m',
#  '11h 00m',
#  '12h 30m',
#  '14h 10m',
#  '15h 25m',
#  '16h 25m',
#  '16h 55m',
#  '24h 10m',
#  '28h 25m',
#  '5h 10m',
#  '8h 05m',
#  '8h 40m',
#  '15h 30m',
#  '19h 05m',
#  '26h 30m',
#  '27h 25m',
#  '5h 30m',
#  '5h 40m',
#  '8h 55m',
#  '10h 05m',
#  '15h 50m',
#  '11h 20m',
#  '5h 30m',
#  '8h 55m',
#  '10h 05m',
#  '8h 40m',
#  '28h 15m',
#  '33h 15m',
#  '8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '15h 50m',
#  '11h 20m',
#  '12h 15m',
#  '13h 10m',
#  '25h 15m',
#  '25h 15m',
#  '8h 15m',
#  '18h 15m',
#  '22h 30m',
#  '22h 35m',
#  '11h 25m',
#  '10h 40m',
# ...

# %%
len(name_titels)
# Out:
# 210

# %%
name_titels[:200]
# Out:
# ['8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 20m',
#  '1h 20m',
#  '1h 20m',
#  '1h 20m',
#  '1h 30m',
#  '1h 20m',
#  '1h 20m',
#  '8h 10m',
#  '15h 35m',
#  '16h 30m',
#  '28h 35m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '24h 50m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '7h 45m',
#  '5h 10m',
#  '8h 05m',
#  '19h 10m',
#  '5h 40m',
#  '7h 10m',
#  '8h 15m',
#  '11h 00m',
#  '12h 30m',
#  '14h 10m',
#  '15h 25m',
#  '16h 25m',
#  '16h 55m',
#  '24h 10m',
#  '28h 25m',
#  '5h 10m',
#  '8h 05m',
#  '8h 40m',
#  '15h 30m',
#  '19h 05m',
#  '26h 30m',
#  '27h 25m',
#  '5h 30m',
#  '5h 40m',
#  '8h 55m',
#  '10h 05m',
#  '15h 50m',
#  '11h 20m',
#  '5h 30m',
#  '8h 55m',
#  '10h 05m',
#  '8h 40m',
#  '28h 15m',
#  '33h 15m',
#  '8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '15h 50m',
#  '11h 20m',
#  '12h 15m',
#  '13h 10m',
#  '25h 15m',
#  '25h 15m',
#  '8h 15m',
#  '18h 15m',
#  '22h 30m',
#  '22h 35m',
#  '11h 25m',
#  '10h 40m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b pr']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="89f2b3df-1f93-44d8-889d-369a5c5540d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="782978f7-3934-4582-91fa-becd4283e15c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c051fdaf-d674-4e7d-8ec8-f82286210e54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="bf171990-a11a-4b1d-8bf8-10b155b55709")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d367da1c-9880-4223-a521-b2351d54dab4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fe06b561-7446-4e88-a834-cec8a1718f4e")>,
# ...

# %%
sname_titels2=[]
for i in titles_tag:
    sname_titels2.append(i.text)
sname_titels2
# Out:
# ['13:30',
#  '12:15',
#  '09:55',
#  '17:10',
#  '18:30',
#  '17:10',
#  '18:30',
#  '06:15',
#  '06:15',
#  '12:45',
#  '16:20',
#  '06:20',
#  '12:45',
#  '16:20',
#  '15:25',
#  '08:00',
#  '07:05',
#  '19:00',
#  '02:35',
#  '02:35',
#  '02:35',
#  '13:25',
#  '02:35',
#  '02:35',
#  '02:35',
#  '09:50',
#  '17:40',
#  '14:45',
#  '19:05',
#  '16:55',
#  '15:45',
#  '14:40',
#  '11:55',
#  '10:25',
#  '08:45',
#  '07:30',
#  '06:30',
#  '06:00',
#  '22:45',
#  '18:30',
#  '17:40',
#  '14:45',
#  '08:45',
#  '19:00',
#  '15:25',
#  '08:00',
#  '07:05',
#  '10:15',
#  '16:55',
#  '10:15',
#  '05:40',
#  '06:00',
#  '11:30',
#  '10:15',
#  '10:15',
#  '05:40',
#  '08:45',
#  '19:20',
#  '14:20',
#  '13:30',
#  '12:15',
#  '09:55',
#  '06:00',
#  '11:30',
#  '08:00',
#  '07:05',
#  '19:00',
#  '19:00',
#  '07:30',
#  '22:45',
#  '18:30',
#  '19:00',
#  '11:30',
#  '12:15',
#  '07:30',
#  '06:00',
#  '11:30',
#  '11:30',
#  '11:30',
#  '11:30',
#  '14:45',
#  '11:30',
#  '09:45',
# ...

# %%
len(sname_titels2)
# Out:
# 210

# %%
sname_titels2[:200]
# Out:
# ['13:30',
#  '12:15',
#  '09:55',
#  '17:10',
#  '18:30',
#  '17:10',
#  '18:30',
#  '06:15',
#  '06:15',
#  '12:45',
#  '16:20',
#  '06:20',
#  '12:45',
#  '16:20',
#  '15:25',
#  '08:00',
#  '07:05',
#  '19:00',
#  '02:35',
#  '02:35',
#  '02:35',
#  '13:25',
#  '02:35',
#  '02:35',
#  '02:35',
#  '09:50',
#  '17:40',
#  '14:45',
#  '19:05',
#  '16:55',
#  '15:45',
#  '14:40',
#  '11:55',
#  '10:25',
#  '08:45',
#  '07:30',
#  '06:30',
#  '06:00',
#  '22:45',
#  '18:30',
#  '17:40',
#  '14:45',
#  '08:45',
#  '19:00',
#  '15:25',
#  '08:00',
#  '07:05',
#  '10:15',
#  '16:55',
#  '10:15',
#  '05:40',
#  '06:00',
#  '11:30',
#  '10:15',
#  '10:15',
#  '05:40',
#  '08:45',
#  '19:20',
#  '14:20',
#  '13:30',
#  '12:15',
#  '09:55',
#  '06:00',
#  '11:30',
#  '08:00',
#  '07:05',
#  '19:00',
#  '19:00',
#  '07:30',
#  '22:45',
#  '18:30',
#  '19:00',
#  '11:30',
#  '12:15',
#  '07:30',
#  '06:00',
#  '11:30',
#  '11:30',
#  '11:30',
#  '11:30',
#  '14:45',
#  '11:30',
#  '09:45',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a4265716-0a03-4ee2-94b9-befb3f108110")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d1f03081-a40e-4d63-b988-d8b88169f4a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f9565995-d8c5-4d32-88bb-2f82f95424f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3bc480a8-b0d4-41ac-a73c-1c1e12edb457")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f908000c-1d1b-411e-bfbc-19cc229b3036")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="0d690337-33cd-439c-8183-41438959dd60")>,
# ...

# %%
dname_titels2=[]
for i in titles_tag:
    dname_titels2.append(i.text)
dname_titels2
# Out:
# ['21:50',
#  '21:50',
#  '21:50',
#  '18:35',
#  '19:55',
#  '18:35',
#  '19:55',
#  '07:35',
#  '07:35',
#  '14:05',
#  '17:40',
#  '07:50',
#  '14:05',
#  '17:40',
#  '23:35',
#  '23:35',
#  '23:35',
#  '23:35\n+ 1 day',
#  '06:35',
#  '08:45',
#  '15:35',
#  '14:15\n+ 1 day',
#  '06:35',
#  '08:45',
#  '15:35',
#  '17:35',
#  '22:50',
#  '22:50',
#  '14:15\n+ 1 day',
#  '22:35',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55\n+ 1 day',
#  '22:55\n+ 1 day',
#  '22:50',
#  '22:50',
#  '17:25',
#  '10:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '15:45',
#  '22:35',
#  '19:10',
#  '15:45',
#  '21:50',
#  '22:50',
#  '15:45',
#  '19:10',
#  '15:45',
#  '17:25',
#  '23:35\n+ 1 day',
#  '23:35\n+ 1 day',
#  '21:50',
#  '21:50',
#  '21:50',
#  '21:50',
#  '22:50',
#  '20:15',
#  '20:15',
#  '20:15\n+ 1 day',
#  '20:15\n+ 1 day',
#  '15:45',
#  '17:00\n+ 1 day',
#  '17:00\n+ 1 day',
# ...

# %%
len(dname_titels2)
# Out:
# 210

# %%
dname_titels2[:200]
# Out:
# ['21:50',
#  '21:50',
#  '21:50',
#  '18:35',
#  '19:55',
#  '18:35',
#  '19:55',
#  '07:35',
#  '07:35',
#  '14:05',
#  '17:40',
#  '07:50',
#  '14:05',
#  '17:40',
#  '23:35',
#  '23:35',
#  '23:35',
#  '23:35\n+ 1 day',
#  '06:35',
#  '08:45',
#  '15:35',
#  '14:15\n+ 1 day',
#  '06:35',
#  '08:45',
#  '15:35',
#  '17:35',
#  '22:50',
#  '22:50',
#  '14:15\n+ 1 day',
#  '22:35',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55\n+ 1 day',
#  '22:55\n+ 1 day',
#  '22:50',
#  '22:50',
#  '17:25',
#  '10:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '10:30\n+ 1 day',
#  '15:45',
#  '22:35',
#  '19:10',
#  '15:45',
#  '21:50',
#  '22:50',
#  '15:45',
#  '19:10',
#  '15:45',
#  '17:25',
#  '23:35\n+ 1 day',
#  '23:35\n+ 1 day',
#  '21:50',
#  '21:50',
#  '21:50',
#  '21:50',
#  '22:50',
#  '20:15',
#  '20:15',
#  '20:15\n+ 1 day',
#  '20:15\n+ 1 day',
#  '15:45',
#  '17:00\n+ 1 day',
#  '17:00\n+ 1 day',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8f0256a3-205f-4a7f-bedc-f37505a0583a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="01f05046-e95d-4d51-9a7c-a437c2c05e1f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2c6b3d91-4921-4487-9f8d-2664334f47eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2a75ddb1-3900-4aee-b6d1-4585029ab8a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="34566c13-c817-449e-8bd6-94f655c9aca1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f7416f9a-23e9-4855-a208-bf41b5fb5b3b")>,
# ...

# %%
id_titels2=[]
for i in titles_tag:
    id_titels2.append(i.text)
id_titels2
# Out:
# ['G8-391/422',
#  'G8-321/422',
#  'G8-319/422',
#  '6E-5208',
#  '6E-6818',
#  '6E-5208',
#  '6E-6818',
#  '6E-5209',
#  '6E-5209',
#  '6E-354',
#  '6E-5217',
#  'UK-873',
#  '6E-354',
#  '6E-5217',
#  'AI-442/839',
#  'AI-806/839',
#  'AI-635/839',
#  'AI-888/839',
#  'I5-338/410',
#  'I5-338/1576',
#  'I5-338/1983',
#  'AI-663/9882',
#  'I5-338/410',
#  'I5-338/1576',
#  'I5-338/1983',
#  'AI-651/9886',
#  'G8-371/572',
#  'G8-382/572',
#  '9I-9657/9882',
#  '6E-6809/281',
#  'UK-902/871',
#  'UK-944/871',
#  'UK-960/871',
#  'UK-994/871',
#  'UK-970/871',
#  'UK-930/871',
#  'UK-928/871',
#  'UK-954/871',
#  'UK-986/871',
#  'UK-996/871',
#  'G8-371/572',
#  'G8-382/572',
#  '6E-932/7137',
#  'AI-888/560',
#  'AI-442/560',
#  'AI-806/560',
#  'AI-635/560',
#  '6E-6078/712',
#  '6E-6809/281',
#  '6E-6078/468',
#  '6E-5202/712',
#  'G8-329/422',
#  'G8-331/572',
#  '6E-6078/712',
#  '6E-6078/468',
#  '6E-5202/712',
#  '6E-932/7137',
#  'AI-631/482/839',
#  'AI-643/472/839',
# ...

# %%
len(name_titels)
# Out:
# 210

# %%
name_titels[:200]
# Out:
# ['8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 20m',
#  '1h 20m',
#  '1h 20m',
#  '1h 20m',
#  '1h 30m',
#  '1h 20m',
#  '1h 20m',
#  '8h 10m',
#  '15h 35m',
#  '16h 30m',
#  '28h 35m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '24h 50m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '7h 45m',
#  '5h 10m',
#  '8h 05m',
#  '19h 10m',
#  '5h 40m',
#  '7h 10m',
#  '8h 15m',
#  '11h 00m',
#  '12h 30m',
#  '14h 10m',
#  '15h 25m',
#  '16h 25m',
#  '16h 55m',
#  '24h 10m',
#  '28h 25m',
#  '5h 10m',
#  '8h 05m',
#  '8h 40m',
#  '15h 30m',
#  '19h 05m',
#  '26h 30m',
#  '27h 25m',
#  '5h 30m',
#  '5h 40m',
#  '8h 55m',
#  '10h 05m',
#  '15h 50m',
#  '11h 20m',
#  '5h 30m',
#  '8h 55m',
#  '10h 05m',
#  '8h 40m',
#  '28h 15m',
#  '33h 15m',
#  '8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '15h 50m',
#  '11h 20m',
#  '12h 15m',
#  '13h 10m',
#  '25h 15m',
#  '25h 15m',
#  '8h 15m',
#  '18h 15m',
#  '22h 30m',
#  '22h 35m',
#  '11h 25m',
#  '10h 40m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3be69fc8-33eb-45c7-a865-2d6da220cf34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="22cbb9b4-2f7e-47b7-9c14-01349ba3ca9c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ca0327e6-f9dd-4743-80d9-d65ba2129a23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="72e4fc04-450d-4014-9c37-67f3b83ca54f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="70071157-ad45-4380-b6fe-2a61a175c55b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="eca83822-c4bf-4b5a-8a81-47ce7ef0b0eb")>,
# ...

# %%
price_titels2=[]
for i in titles_tag:
    price_titels2.append(i.text)
price_titels2
# Out:
# ['4,262',
#  '4,262',
#  '4,262',
#  '4,263',
#  '4,263',
#  '4,657',
#  '4,657',
#  '5,208',
#  '5,602',
#  '5,681',
#  '5,891',
#  '5,996',
#  '6,074',
#  '6,284',
#  '7,584',
#  '7,584',
#  '7,584',
#  '7,584',
#  '8,044',
#  '8,044',
#  '8,044',
#  '8,463',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,581',
#  '9,093',
#  '9,093',
#  '9,776',
#  '9,828',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,987',
#  '9,987',
#  '10,427',
#  '10,587',
#  '10,587',
#  '10,587',
#  '10,587',
#  '10,721',
#  '10,721',
#  '10,721',
#  '10,721',
#  '11,377',
#  '11,403',
#  '11,613',
#  '11,613',
#  '11,613',
#  '11,687',
#  '12,079',
#  '12,099',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,297',
#  '13,086',
#  '13,086',
#  '13,086',
#  '13,086',
#  '13,241',
#  '13,608',
#  '13,608',
#  '13,687',
#  '14,038',
#  '14,079',
#  '14,133',
#  '15,413',
#  '15,761',
#  '15,761',
#  '16,154',
#  '16,154',
# ...

# %%
len(price_titels2)
# Out:
# 208

# %%
price_titels2[:200]
# Out:
# ['4,262',
#  '4,262',
#  '4,262',
#  '4,263',
#  '4,263',
#  '4,657',
#  '4,657',
#  '5,208',
#  '5,602',
#  '5,681',
#  '5,891',
#  '5,996',
#  '6,074',
#  '6,284',
#  '7,584',
#  '7,584',
#  '7,584',
#  '7,584',
#  '8,044',
#  '8,044',
#  '8,044',
#  '8,463',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,581',
#  '9,093',
#  '9,093',
#  '9,776',
#  '9,828',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,987',
#  '9,987',
#  '10,427',
#  '10,587',
#  '10,587',
#  '10,587',
#  '10,587',
#  '10,721',
#  '10,721',
#  '10,721',
#  '10,721',
#  '11,377',
#  '11,403',
#  '11,613',
#  '11,613',
#  '11,613',
#  '11,687',
#  '12,079',
#  '12,099',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,297',
#  '13,086',
#  '13,086',
#  '13,086',
#  '13,086',
#  '13,241',
#  '13,608',
#  '13,608',
#  '13,687',
#  '14,038',
#  '14,079',
#  '14,133',
#  '15,413',
#  '15,761',
#  '15,761',
#  '16,154',
#  '16,154',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c23add52-a473-4dc0-8228-89baa3244c2c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b83a02f8-6bf7-4958-b0a9-1ec29657c1d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="953fae51-87ed-44f9-a84d-c341fdf42993")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="29027f9c-9000-4d5c-8bd8-189e9b846c51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a0fb5237-6b44-4320-b586-2d3411ab2c33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="717a3977-d124-442e-9eeb-4fd0023f41b0")>,
# ...

# %%
name_titels1=[]
for i in titles_tag:
    name_titels1.append(i.text)
name_titels1
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
# ...

# %%
len(name_titels1)
# Out:
# 210

# %%
name_titels1[:200]
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d2c41c49-e786-4b6e-b3bd-5ae15c0c8eb6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8868e0b8-4d45-48c9-aaa9-6f079602aed0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="5f26e23f-4b3f-49cc-ac09-928467390b91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="5275536e-c003-4d2b-af6d-1e9fddd5e238")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="df83a09d-9d48-4b2f-af1e-53bb81c4a32c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="354f17ef-44e5-43bd-940d-3bf4e3555182")>,
# ...

# %%
spoint_titels2=[]
for i in titles_tag:
    spoint_titels2.append(i.text)
spoint_titels2
# Out:
# ['Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
# ...

# %%
NAME1= []
for i in range(1,len(spoint_titels2),2):
    NAME1.append(spoint_titels2[i])
NAME1
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
len(NAME1)
# Out:
# 210

# %%
NAME1[:200]
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
NAME2= []
for i in range(2,len(spoint_titels2),2):
    NAME2.append(spoint_titels2[i])
NAME2
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
len(NAME2)
# Out:
# 209

# %%
NAME2[:200]
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels1[:200]
copy['flight id']=name_titels[:200]
copy['price']=price_titels2[:200]
copy['arrival time']=sname_titels2[:200]
copy['departure time']=dname_titels2[:200]
copy['hours taken']=name_titels[:200]
copy['starting point']=NAME2[:200]
copy['destination']=NAME1[:200]

# %%
copy
# Out:
#          Name       flight id  price arrival time departure time hours taken  \
# 0    Go First      G8-391/422  4,262        13:30          21:50      8h 20m
# 1    Go First      G8-321/422  4,262        12:15          21:50      9h 35m
# 2    Go First      G8-319/422  4,262        09:55          21:50     11h 55m
# 3      IndiGo         6E-5208  4,263        17:10          18:35      1h 25m
# 4      IndiGo         6E-6818  4,263        18:30          19:55      1h 25m
# ..        ...             ...    ...          ...            ...         ...
# 195   Vistara  UK-860/847/844               06:50
# 196  Go First      G8-123/519               06:05
# 197  Go First      G8-123/519               06:05
# 198   Vistara  UK-830/673/622               10:05
# 199   Vistara  UK-860/673/622               06:50
#
#     starting point destination
# 0           Mumbai   Hyderabad
# 1           Mumbai   Hyderabad
# 2           Mumbai   Hyderabad
# 3           Mumbai   Hyderabad
# ...

# %%
copy.to_csv('flight8.csv')

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels2[:235]+name_titels1[:200]
copy['id']=name_titels0[:235]
copy['price']=price_titels12[:235]
copy['arrival time']=sname_titels2[:235]
copy['departure time']=dname_titels2[:235]
copy['hours taken']=name_titels12[:235]
copy['starting point']=NAME4[:235]
copy['destination']=NAME2[:235]

# %%
url='https://www.tripodeal.com/results?tid=617a7d1ae01700724423568c'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='duration']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="41e86605-f297-461b-8b70-047e05308352")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="3536dbdc-8622-4434-888f-31aa6be0678f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="9b9d656b-d660-4720-92b8-bc03bd0da89b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="c3322ae8-787d-45a9-b1c3-7b1904acd610")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="775009d7-93f8-4b97-a48f-34846a798c36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="70906400-11cc-41fd-a8d5-2b895854910c")>,
# ...

# %%
name_titels=[]
for i in titles_tag:
    name_titels.append(i.text)
name_titels
# Out:
# ['09h 10m',
#  '09h 45m',
#  '12h 00m',
#  '02h 10m',
#  '02h 15m',
#  '07h 15m',
#  '02h 05m',
#  '02h 10m',
#  '02h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 20m',
#  '02h 20m',
#  '02h 20m',
#  '04h 20m',
#  '05h 30m',
#  '06h 15m',
#  '06h 45m',
#  '07h 10m',
#  '08h 45m',
#  '09h 05m',
#  '09h 30m',
#  '10h 00m',
#  '10h 15m',
#  '10h 45m',
#  '13h 10m',
#  '04h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 20m',
#  '08h 10m',
#  '08h 45m',
#  '09h 15m',
#  '11h 20m',
#  '14h 10m',
#  '17h 00m',
#  '06h 00m',
#  '13h 55m',
#  '08h 20m',
#  '11h 20m',
#  '07h 45m',
#  '08h 05m',
#  '06h 20m',
#  '08h 05m',
#  '09h 15m',
#  '10h 10m',
#  '10h 35m',
#  '11h 25m',
#  '11h 45m',
#  '12h 00m',
#  '12h 05m',
#  '12h 45m',
#  '12h 55m',
#  '13h 25m',
#  '13h 45m',
#  '14h 05m',
#  '14h 55m',
#  '19h 00m',
#  '20h 10m',
#  '21h 30m',
#  '22h 20m',
#  '23h 00m',
#  '24h 20m',
#  '25h 45m',
#  '26h 55m',
#  '05h 25m',
#  '16h 20m',
#  '11h 10m',
# ...

# %%
len(name_titels)
# Out:
# 112

# %%
name_titels[:110]
# Out:
# ['09h 10m',
#  '09h 45m',
#  '12h 00m',
#  '02h 10m',
#  '02h 15m',
#  '07h 15m',
#  '02h 05m',
#  '02h 10m',
#  '02h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 20m',
#  '02h 20m',
#  '02h 20m',
#  '04h 20m',
#  '05h 30m',
#  '06h 15m',
#  '06h 45m',
#  '07h 10m',
#  '08h 45m',
#  '09h 05m',
#  '09h 30m',
#  '10h 00m',
#  '10h 15m',
#  '10h 45m',
#  '13h 10m',
#  '04h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 20m',
#  '08h 10m',
#  '08h 45m',
#  '09h 15m',
#  '11h 20m',
#  '14h 10m',
#  '17h 00m',
#  '06h 00m',
#  '13h 55m',
#  '08h 20m',
#  '11h 20m',
#  '07h 45m',
#  '08h 05m',
#  '06h 20m',
#  '08h 05m',
#  '09h 15m',
#  '10h 10m',
#  '10h 35m',
#  '11h 25m',
#  '11h 45m',
#  '12h 00m',
#  '12h 05m',
#  '12h 45m',
#  '12h 55m',
#  '13h 25m',
#  '13h 45m',
#  '14h 05m',
#  '14h 55m',
#  '19h 00m',
#  '20h 10m',
#  '21h 30m',
#  '22h 20m',
#  '23h 00m',
#  '24h 20m',
#  '25h 45m',
#  '26h 55m',
#  '05h 25m',
#  '16h 20m',
#  '11h 10m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='departure-time base-time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="a6dcf090-b833-445e-973d-2cf2cd2ff3a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="5d0a2b49-8c0a-40d3-b10a-66b6cb4d4c52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="16d9431e-1df3-4b5b-b37a-a02136cdf29a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="5bbc6ff9-9638-4b1e-bc09-9429f1e5adf1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="6c7ba684-4d89-4433-b4f0-06172dc2f37a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="86bdbbda-677f-4a38-81a0-df639069156d")>,
# ...

# %%
sname_titels2=[]
for i in titles_tag:
    sname_titels2.append(i.text)
sname_titels2
# Out:
# ['21:25',
#  '21:00',
#  '18:35',
#  '07:20',
#  '19:35',
#  '06:05',
#  '17:00',
#  '17:40',
#  '23:05',
#  '06:45',
#  '07:55',
#  '17:45',
#  '21:15',
#  '07:05',
#  '19:30',
#  '20:35',
#  '07:00',
#  '05:30',
#  '11:20',
#  '12:55',
#  '05:30',
#  '07:50',
#  '21:50',
#  '06:45',
#  '07:00',
#  '07:20',
#  '21:20',
#  '06:15',
#  '16:15',
#  '09:40',
#  '13:00',
#  '14:45',
#  '08:10',
#  '09:35',
#  '12:40',
#  '12:10',
#  '21:25',
#  '18:35',
#  '07:10',
#  '09:35',
#  '16:50',
#  '13:00',
#  '12:50',
#  '09:15',
#  '14:40',
#  '15:00',
#  '12:50',
#  '11:40',
#  '21:40',
#  '10:20',
#  '09:30',
#  '09:00',
#  '19:50',
#  '08:50',
#  '08:00',
#  '18:55',
#  '07:30',
#  '07:00',
#  '17:45',
#  '16:55',
#  '12:50',
#  '11:40',
#  '10:20',
#  '09:30',
#  '08:50',
#  '07:30',
#  '19:00',
#  '17:50',
#  '15:30',
#  '15:30',
#  '20:40',
#  '06:10',
#  '17:20',
#  '20:40',
#  '19:50',
#  '06:10',
#  '17:35',
#  '17:20',
#  '15:00',
#  '08:05',
#  '06:15',
#  '11:55',
#  '14:15',
# ...

# %%
len(sname_titels2)
# Out:
# 112

# %%
sname_titels2[:110]
# Out:
# ['21:25',
#  '21:00',
#  '18:35',
#  '07:20',
#  '19:35',
#  '06:05',
#  '17:00',
#  '17:40',
#  '23:05',
#  '06:45',
#  '07:55',
#  '17:45',
#  '21:15',
#  '07:05',
#  '19:30',
#  '20:35',
#  '07:00',
#  '05:30',
#  '11:20',
#  '12:55',
#  '05:30',
#  '07:50',
#  '21:50',
#  '06:45',
#  '07:00',
#  '07:20',
#  '21:20',
#  '06:15',
#  '16:15',
#  '09:40',
#  '13:00',
#  '14:45',
#  '08:10',
#  '09:35',
#  '12:40',
#  '12:10',
#  '21:25',
#  '18:35',
#  '07:10',
#  '09:35',
#  '16:50',
#  '13:00',
#  '12:50',
#  '09:15',
#  '14:40',
#  '15:00',
#  '12:50',
#  '11:40',
#  '21:40',
#  '10:20',
#  '09:30',
#  '09:00',
#  '19:50',
#  '08:50',
#  '08:00',
#  '18:55',
#  '07:30',
#  '07:00',
#  '17:45',
#  '16:55',
#  '12:50',
#  '11:40',
#  '10:20',
#  '09:30',
#  '08:50',
#  '07:30',
#  '19:00',
#  '17:50',
#  '15:30',
#  '15:30',
#  '20:40',
#  '06:10',
#  '17:20',
#  '20:40',
#  '19:50',
#  '06:10',
#  '17:35',
#  '17:20',
#  '15:00',
#  '08:05',
#  '06:15',
#  '11:55',
#  '14:15',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='arrival-time base-time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="a2596c85-28f1-48dc-91a5-4db7bc7e01a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="1ac5afb4-68cd-48bd-bc7f-352b28af5e2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="6be4a23c-089c-43f3-a88a-dce06f65b371")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="ad906443-5111-4b03-b0ac-f7b1b02d7ebe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="5f7e6442-9949-4530-b4ed-8e8cea62856b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="3798f6ee-ae89-4f76-ab39-82ad67644ec9")>,
# ...

# %%
dname_titels2=[]
for i in titles_tag:
    dname_titels2.append(i.text)
dname_titels2
# Out:
# ['06:35',
#  '06:45',
#  '06:35',
#  '09:30',
#  '21:50',
#  '13:20',
#  '19:05',
#  '19:50',
#  '01:15',
#  '09:00',
#  '10:10',
#  '20:00',
#  '23:30',
#  '09:25',
#  '21:50',
#  '22:55',
#  '11:20',
#  '11:00',
#  '17:35',
#  '19:40',
#  '12:40',
#  '16:35',
#  '06:55',
#  '16:15',
#  '17:00',
#  '17:35',
#  '08:05',
#  '19:25',
#  '20:25',
#  '11:55',
#  '15:15',
#  '17:00',
#  '10:30',
#  '17:45',
#  '21:25',
#  '21:25',
#  '08:45',
#  '08:45',
#  '00:10',
#  '15:35',
#  '06:45',
#  '21:20',
#  '00:10',
#  '17:00',
#  '22:45',
#  '21:20',
#  '20:55',
#  '20:55',
#  '07:50',
#  '20:55',
#  '20:55',
#  '20:45',
#  '07:50',
#  '20:55',
#  '20:45',
#  '07:50',
#  '20:55',
#  '20:45',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '20:45',
#  '20:45',
#  '20:55',
#  '07:50',
#  '07:50',
#  '19:00',
#  '08:50',
#  '20:25',
#  '20:25',
#  '08:50',
#  '20:25',
#  '20:15',
#  '20:25',
#  '20:25',
#  '20:25',
#  '18:00',
#  '20:25',
# ...

# %%
len(dname_titels2)
# Out:
# 112

# %%
dname_titels2[:110]
# Out:
# ['06:35',
#  '06:45',
#  '06:35',
#  '09:30',
#  '21:50',
#  '13:20',
#  '19:05',
#  '19:50',
#  '01:15',
#  '09:00',
#  '10:10',
#  '20:00',
#  '23:30',
#  '09:25',
#  '21:50',
#  '22:55',
#  '11:20',
#  '11:00',
#  '17:35',
#  '19:40',
#  '12:40',
#  '16:35',
#  '06:55',
#  '16:15',
#  '17:00',
#  '17:35',
#  '08:05',
#  '19:25',
#  '20:25',
#  '11:55',
#  '15:15',
#  '17:00',
#  '10:30',
#  '17:45',
#  '21:25',
#  '21:25',
#  '08:45',
#  '08:45',
#  '00:10',
#  '15:35',
#  '06:45',
#  '21:20',
#  '00:10',
#  '17:00',
#  '22:45',
#  '21:20',
#  '20:55',
#  '20:55',
#  '07:50',
#  '20:55',
#  '20:55',
#  '20:45',
#  '07:50',
#  '20:55',
#  '20:45',
#  '07:50',
#  '20:55',
#  '20:45',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '07:50',
#  '20:45',
#  '20:45',
#  '20:55',
#  '07:50',
#  '07:50',
#  '19:00',
#  '08:50',
#  '20:25',
#  '20:25',
#  '08:50',
#  '20:25',
#  '20:15',
#  '20:25',
#  '20:25',
#  '20:25',
#  '18:00',
#  '20:25',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='bottom']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="8696e813-ea7c-4d78-9b64-2de17e438b98")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="5550a019-2c6c-4508-b37d-7ec5c086d080")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="ddb68ce1-d8ec-4983-aa50-72261c2c1eb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="688714e1-51e2-4e0b-bc3d-b1bf8deb84f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="09d38820-ab6a-4518-ad00-ef92d0b22cc7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="e4b7ecbf-9aef-4995-9753-a444a693259f")>,
# ...

# %%
id_titels2=[]
for i in titles_tag:
    id_titels2.append(i.text)
id_titels2
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
len(id_titels2)
# Out:
# 112

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='text-muted d-none d-lg-inline ']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="6c6104bd-b1c8-4771-a4bd-cc900e99cab2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="1aa222c1-647f-408a-ab28-f607f3d8dad3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="693a86a1-543f-4513-bc93-2039f5ec3ac1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="8cd5a760-3b00-49b7-8e4b-ffa95bccc8ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="00ae387f-da83-4c1a-b269-5826236bc65a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="e7aa2ce9-e07b-4bf8-9bec-6ca3934066f7")>,
# ...

# %%
name_titels2=[]
for i in titles_tag:
    name_titels2.append(i.text)
name_titels2
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go Air',
#  'Go Air',
#  'Go Air',
#  'Spice Jet',
#  'Vistara',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Vistara',
#  'Indigo Air',
#  'Vistara',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Spice Jet',
#  'Air Asia',
#  'Indigo Air',
#  'Indigo Air',
#  'Vistara',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Indigo Air',
#  'Air Asia',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
len(name_titels2)
# Out:
# 112

# %%
name_titels2[:110]
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go Air',
#  'Go Air',
#  'Go Air',
#  'Spice Jet',
#  'Vistara',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Vistara',
#  'Indigo Air',
#  'Vistara',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Spice Jet',
#  'Air Asia',
#  'Indigo Air',
#  'Indigo Air',
#  'Vistara',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Indigo Air',
#  'Air Asia',
#  'Indigo Air',
#  'Indigo Air',
#  'Indigo Air',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='money']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="81035ab2-14fc-4dc5-8f2f-5dfdf36c9fb9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="5ffe0730-8766-4f89-a5ca-6ce601832fe8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="63ddb21d-eb32-40d6-aea9-874e33d0c189")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="7c84a84c-36a1-41d0-bf39-dd468add84b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="97a3551b-b0f3-4964-9080-b2d6c5041ae1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="cdaefd85-16ba-4590-b205-0857755686ca")>,
# ...

# %%
price_titels2=[]
for i in titles_tag:
    price_titels2.append(i.text)
price_titels2
# Out:
# ['₹6454',
#  '₹6453',
#  '₹12230',
#  '₹6453',
#  '₹6353',
#  '₹6453',
#  '₹6353',
#  '₹6453',
#  '₹6353',
#  '₹6454',
#  '₹6354',
#  '₹6454',
#  '₹6354',
#  '₹6454',
#  '₹6354',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6455',
#  '₹6355',
#  '₹6456',
#  '₹6356',
#  '₹6665',
#  '₹6565',
#  '₹6875',
#  '₹6775',
#  '₹6875',
#  '₹6775',
#  '₹6875',
#  '₹6775',
#  '₹7264',
#  '₹7164',
#  '₹7264',
#  '₹7164',
#  '₹7264',
#  '₹7164',
#  '₹7264',
#  '₹7164',
#  '₹7264',
#  '₹7164',
#  '₹7264',
#  '₹7164',
#  '₹8612',
#  '₹8512',
# ...

# %%
NAME1= []
for i in range(2,len(price_titels2),2):
    NAME1.append(price_titels2[i])
NAME1
# Out:
# ['₹12230',
#  '₹6353',
#  '₹6353',
#  '₹6353',
#  '₹6354',
#  '₹6354',
#  '₹6354',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6356',
#  '₹6565',
#  '₹6775',
#  '₹6775',
#  '₹6775',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹8512',
#  '₹8512',
#  '₹8796',
#  '₹9009',
#  '₹9285',
#  '₹9285',
#  '₹9773',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10345',
#  '₹10345',
#  '₹10975',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11763',
# ...

# %%
len(NAME1)
# Out:
# 113

# %%
NAME1[:110]
# Out:
# ['₹12230',
#  '₹6353',
#  '₹6353',
#  '₹6353',
#  '₹6354',
#  '₹6354',
#  '₹6354',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6355',
#  '₹6356',
#  '₹6565',
#  '₹6775',
#  '₹6775',
#  '₹6775',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹7164',
#  '₹8512',
#  '₹8512',
#  '₹8796',
#  '₹9009',
#  '₹9285',
#  '₹9285',
#  '₹9773',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10240',
#  '₹10345',
#  '₹10345',
#  '₹10975',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11710',
#  '₹11763',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='name ']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="9e57c27e-c749-49c7-8903-a3ef7ec7f43b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="c106b868-ae48-45e6-b478-08025cfe79cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="304b751c-6477-43f2-897f-dd6cc2119417")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="9b95ea17-fc55-4fb8-aaf1-769c02bd50cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="2ef3a033-0485-4325-8992-267caf5e7481")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d5885ef82a9bdc2f428a7acddefc687d", element="03fe8667-11f1-4fab-b2fa-1359e4042af4")>,
# ...

# %%
price_titels2=[]
for i in titles_tag:
    price_titels2.append(i.text)
price_titels2
# Out:
# ['New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
# ...

# %%
NAME2= []
for i in range(2,len(price_titels2),2):
    NAME2.append(price_titels2[i])
NAME2
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
len(NAME2)
# Out:
# 111

# %%
NAME2[:110]
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
NAME3= []
for i in range(1,len(price_titels2),2):
    NAME3.append(price_titels2[i])
NAME3
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
len(NAME3)
# Out:
# 112

# %%
NAME3[:110]
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag

# %%
name_titels0=[]
for i in titles_tag:
    name_titels0.append(i.text)
name_titels0

# %%
len(name_titels0)

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels2[:110]

copy['price']=NAME1[:110]
copy['arrival time']=sname_titels2[:110]
copy['departure time']=dname_titels2[:110]
copy['hours taken']=name_titels[:110]
copy['starting point']=NAME2[:110]
copy['destination']=NAME3[:110]

# %%
copy
# Out:
#           Name   price arrival time departure time hours taken starting point  \
# 0     Air Asia  ₹12230        21:25          06:35     09h 10m      New Delhi
# 1     Air Asia   ₹6353        21:00          06:45     09h 45m      New Delhi
# 2     Air Asia   ₹6353        18:35          06:35     12h 00m      New Delhi
# 3       Go Air   ₹6353        07:20          09:30     02h 10m      New Delhi
# 4       Go Air   ₹6354        19:35          21:50     02h 15m      New Delhi
# ..         ...     ...          ...            ...         ...            ...
# 105  Air India  ₹15123        13:30          19:00     29h 30m      New Delhi
# 106    Vistara  ₹15123        17:35          07:50     14h 15m      New Delhi
# 107  Air India  ₹15188        10:40          20:45     10h 05m      New Delhi
# 108  Air India  ₹20005        06:50          21:15     14h 25m      New Delhi
# 109  Air India  ₹20110        20:15          21:15     25h 00m      New Delhi
#
#     destination
# ...

# %%
copy.to_csv('flight.csv')

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels2[:235]
copy['id']=name_titels0[:235]
copy['price']=price_titels12[:235]
copy['arrival time']=sname_titels2[:235]
copy['departure time']=dname_titels2[:235]
copy['hours taken']=name_titels12[:235]
copy['starting point']=NAME4[:235]
copy['destination']=NAME2[:235]

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=M&viewName=normal&flexi=0&noOfSegments=2&origin_0=BOM&destination_0=HYD&originCountry_0=IN&destinationCountry_0=IN&flight_depart_date_0=04%2F11%2F2021&origin_1=HYD&destination_1=DEL&originCountry_1=IN&destinationCountry_1=IN&flight_depart_date_1=05%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1551168252934'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="181c9e7c-f0f5-42ca-b3e7-e139b69e6094")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="68ba0971-7b9b-48e0-bc00-77c271a77d7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c26e6d0d-31fa-4655-b29c-9fbbedb9626c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a22b6c5c-3c3b-4bb9-b9ec-2c1365af5c7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="882105f1-f497-450b-8088-63107e42fa6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d67be355-856d-4dbf-8d36-8441e7a68115")>,
# ...

# %%
name_titels0=[]
for i in titles_tag:
    name_titels0.append(i.text)
name_titels0
# Out:
# ['G8-391/422',
#  'G8-321/422',
#  'G8-319/422',
#  '6E-5208',
#  '6E-6818',
#  '6E-5208',
#  '6E-6818',
#  'AI-615',
#  '6E-354',
#  '6E-5217',
#  'UK-873',
#  '6E-354',
#  '6E-5217',
#  'AI-442/839',
#  'AI-806/839',
#  'AI-635/839',
#  'AI-888/839',
#  '6E-5312',
#  'I5-338/410',
#  'I5-338/1576',
#  'I5-338/1983',
#  '6E-5312',
#  'AI-663/9882',
#  'I5-338/410',
#  'I5-338/1576',
#  'I5-338/1983',
#  'AI-651/9886',
#  'G8-371/572',
#  'G8-382/572',
#  '9I-9657/9882',
#  '6E-6809/281',
#  'UK-902/871',
#  'UK-944/871',
#  'UK-960/871',
#  'UK-994/871',
#  'UK-970/871',
#  'UK-930/871',
#  'UK-928/871',
#  'UK-954/871',
#  'UK-986/871',
#  'UK-996/871',
#  'G8-371/572',
#  'G8-382/572',
#  '6E-6809/281',
#  '6E-932/7137',
#  '6E-6078/468',
#  '6E-6078/712',
#  '6E-5202/712',
#  'G8-327/422',
#  'G8-329/422',
#  'G8-331/572',
#  'UK-843/868/897',
#  '6E-6078/468',
#  '6E-932/7137',
#  '6E-6078/712',
#  '6E-5202/712',
#  'G8-391/422',
#  'G8-321/422',
#  'G8-319/422',
# ...

# %%
len(name_titels0)
# Out:
# 241

# %%
name_titels0[:235]
# Out:
# ['G8-391/422',
#  'G8-321/422',
#  'G8-319/422',
#  '6E-5208',
#  '6E-6818',
#  '6E-5208',
#  '6E-6818',
#  'AI-615',
#  '6E-354',
#  '6E-5217',
#  'UK-873',
#  '6E-354',
#  '6E-5217',
#  'AI-442/839',
#  'AI-806/839',
#  'AI-635/839',
#  'AI-888/839',
#  '6E-5312',
#  'I5-338/410',
#  'I5-338/1576',
#  'I5-338/1983',
#  '6E-5312',
#  'AI-663/9882',
#  'I5-338/410',
#  'I5-338/1576',
#  'I5-338/1983',
#  'AI-651/9886',
#  'G8-371/572',
#  'G8-382/572',
#  '9I-9657/9882',
#  '6E-6809/281',
#  'UK-902/871',
#  'UK-944/871',
#  'UK-960/871',
#  'UK-994/871',
#  'UK-970/871',
#  'UK-930/871',
#  'UK-928/871',
#  'UK-954/871',
#  'UK-986/871',
#  'UK-996/871',
#  'G8-371/572',
#  'G8-382/572',
#  '6E-6809/281',
#  '6E-932/7137',
#  '6E-6078/468',
#  '6E-6078/712',
#  '6E-5202/712',
#  'G8-327/422',
#  'G8-329/422',
#  'G8-331/572',
#  'UK-843/868/897',
#  '6E-6078/468',
#  '6E-932/7137',
#  '6E-6078/712',
#  '6E-5202/712',
#  'G8-391/422',
#  'G8-321/422',
#  'G8-319/422',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="92cb563f-5e71-4aa0-82c8-e838122ab9ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d688d811-f44f-475d-838e-17094b598bbb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c99abc1d-d8e8-4213-9f9a-397e13dbf81c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2d12fb4c-2cd7-4544-84c1-d18fcf5c6d66")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d25941d6-2322-4d71-90d4-4f8cacf2a0e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2d6c4628-dc93-4eb0-8fec-9c64481d3ec1")>,
# ...

# %%
name_titels12=[]
for i in titles_tag:
    name_titels12.append(i.text)
name_titels12
# Out:
# ['8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 30m',
#  '1h 20m',
#  '1h 20m',
#  '1h 30m',
#  '1h 20m',
#  '1h 20m',
#  '8h 10m',
#  '15h 35m',
#  '16h 30m',
#  '28h 35m',
#  '1h 20m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '1h 20m',
#  '24h 50m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '7h 45m',
#  '5h 10m',
#  '8h 05m',
#  '19h 10m',
#  '5h 40m',
#  '7h 10m',
#  '8h 15m',
#  '11h 00m',
#  '12h 30m',
#  '14h 10m',
#  '15h 25m',
#  '16h 25m',
#  '16h 55m',
#  '24h 10m',
#  '28h 25m',
#  '5h 10m',
#  '8h 05m',
#  '5h 40m',
#  '8h 40m',
#  '8h 55m',
#  '5h 30m',
#  '10h 05m',
#  '13h 50m',
#  '15h 50m',
#  '11h 20m',
#  '30h 50m',
#  '8h 55m',
#  '8h 40m',
#  '5h 30m',
#  '10h 05m',
#  '8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '13h 50m',
#  '15h 50m',
#  '11h 20m',
#  '12h 15m',
#  '13h 10m',
#  '25h 15m',
#  '18h 15m',
#  '22h 30m',
#  '22h 35m',
#  '10h 40m',
#  '11h 25m',
#  '30h 50m',
#  '16h 55m',
#  '7h 40m',
#  '33h 20m',
# ...

# %%
len(name_titels12)
# Out:
# 241

# %%
name_titels12[:235]
# Out:
# ['8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 25m',
#  '1h 30m',
#  '1h 20m',
#  '1h 20m',
#  '1h 30m',
#  '1h 20m',
#  '1h 20m',
#  '8h 10m',
#  '15h 35m',
#  '16h 30m',
#  '28h 35m',
#  '1h 20m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '1h 20m',
#  '24h 50m',
#  '4h 00m',
#  '6h 10m',
#  '13h 00m',
#  '7h 45m',
#  '5h 10m',
#  '8h 05m',
#  '19h 10m',
#  '5h 40m',
#  '7h 10m',
#  '8h 15m',
#  '11h 00m',
#  '12h 30m',
#  '14h 10m',
#  '15h 25m',
#  '16h 25m',
#  '16h 55m',
#  '24h 10m',
#  '28h 25m',
#  '5h 10m',
#  '8h 05m',
#  '5h 40m',
#  '8h 40m',
#  '8h 55m',
#  '5h 30m',
#  '10h 05m',
#  '13h 50m',
#  '15h 50m',
#  '11h 20m',
#  '30h 50m',
#  '8h 55m',
#  '8h 40m',
#  '5h 30m',
#  '10h 05m',
#  '8h 20m',
#  '9h 35m',
#  '11h 55m',
#  '13h 50m',
#  '15h 50m',
#  '11h 20m',
#  '12h 15m',
#  '13h 10m',
#  '25h 15m',
#  '18h 15m',
#  '22h 30m',
#  '22h 35m',
#  '10h 40m',
#  '11h 25m',
#  '30h 50m',
#  '16h 55m',
#  '7h 40m',
#  '33h 20m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b pr']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1a8aaca8-d88d-4e6d-bd05-eef0ffc02e37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4d7f3c44-ae1a-4055-a6b7-00904ea0da89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="bff15373-63ef-43fa-ba41-be3f433a74db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f03b6cdb-a7ce-4b53-98af-7dc50381384b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="9307e7ad-d3c7-4b0a-af1f-eba887cf2f85")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2076e729-226e-4ba5-9562-5131a586b48d")>,
# ...

# %%
sname_titels2=[]
for i in titles_tag:
    sname_titels2.append(i.text)
sname_titels2
# Out:
# ['13:30',
#  '12:15',
#  '09:55',
#  '17:10',
#  '18:30',
#  '17:10',
#  '18:30',
#  '05:45',
#  '12:45',
#  '16:20',
#  '06:20',
#  '12:45',
#  '16:20',
#  '15:25',
#  '08:00',
#  '07:05',
#  '19:00',
#  '10:45',
#  '02:35',
#  '02:35',
#  '02:35',
#  '10:45',
#  '13:25',
#  '02:35',
#  '02:35',
#  '02:35',
#  '09:50',
#  '17:40',
#  '14:45',
#  '19:05',
#  '16:55',
#  '15:45',
#  '14:40',
#  '11:55',
#  '10:25',
#  '08:45',
#  '07:30',
#  '06:30',
#  '06:00',
#  '22:45',
#  '18:30',
#  '17:40',
#  '14:45',
#  '16:55',
#  '08:45',
#  '10:15',
#  '10:15',
#  '05:40',
#  '08:00',
#  '06:00',
#  '11:30',
#  '13:35',
#  '10:15',
#  '08:45',
#  '10:15',
#  '05:40',
#  '13:30',
#  '12:15',
#  '09:55',
#  '08:00',
#  '06:00',
#  '11:30',
#  '08:00',
#  '07:05',
#  '19:00',
#  '22:45',
#  '18:30',
#  '19:00',
#  '12:15',
#  '11:30',
#  '16:05',
#  '06:00',
#  '11:30',
#  '13:35',
#  '11:30',
#  '11:30',
#  '11:30',
#  '14:45',
#  '11:30',
#  '09:45',
#  '07:05',
#  '07:05',
#  '21:00',
# ...

# %%
len(sname_titels2)
# Out:
# 241

# %%
sname_titels2[:235]
# Out:
# ['13:30',
#  '12:15',
#  '09:55',
#  '17:10',
#  '18:30',
#  '17:10',
#  '18:30',
#  '05:45',
#  '12:45',
#  '16:20',
#  '06:20',
#  '12:45',
#  '16:20',
#  '15:25',
#  '08:00',
#  '07:05',
#  '19:00',
#  '10:45',
#  '02:35',
#  '02:35',
#  '02:35',
#  '10:45',
#  '13:25',
#  '02:35',
#  '02:35',
#  '02:35',
#  '09:50',
#  '17:40',
#  '14:45',
#  '19:05',
#  '16:55',
#  '15:45',
#  '14:40',
#  '11:55',
#  '10:25',
#  '08:45',
#  '07:30',
#  '06:30',
#  '06:00',
#  '22:45',
#  '18:30',
#  '17:40',
#  '14:45',
#  '16:55',
#  '08:45',
#  '10:15',
#  '10:15',
#  '05:40',
#  '08:00',
#  '06:00',
#  '11:30',
#  '13:35',
#  '10:15',
#  '08:45',
#  '10:15',
#  '05:40',
#  '13:30',
#  '12:15',
#  '09:55',
#  '08:00',
#  '06:00',
#  '11:30',
#  '08:00',
#  '07:05',
#  '19:00',
#  '22:45',
#  '18:30',
#  '19:00',
#  '12:15',
#  '11:30',
#  '16:05',
#  '06:00',
#  '11:30',
#  '13:35',
#  '11:30',
#  '11:30',
#  '11:30',
#  '14:45',
#  '11:30',
#  '09:45',
#  '07:05',
#  '07:05',
#  '21:00',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fb40ef22-2c37-4aa8-89d6-bd5fdc9ac451")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ef089ca9-04f5-4cd3-b513-9ac6074c1610")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ba8ec200-3f77-444e-add1-5a942340886f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="54d9d6c9-8d01-4999-9a01-c4484378adec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="799473b1-908b-4e6b-9754-33c3075cd246")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f357b172-68ad-4dd8-8ee6-fc6761005f8b")>,
# ...

# %%
dname_titels2=[]
for i in titles_tag:
    dname_titels2.append(i.text)
dname_titels2
# Out:
# ['21:50',
#  '21:50',
#  '21:50',
#  '18:35',
#  '19:55',
#  '18:35',
#  '19:55',
#  '07:15',
#  '14:05',
#  '17:40',
#  '07:50',
#  '14:05',
#  '17:40',
#  '23:35',
#  '23:35',
#  '23:35',
#  '23:35\n+ 1 day',
#  '12:05',
#  '06:35',
#  '08:45',
#  '15:35',
#  '12:05',
#  '14:15\n+ 1 day',
#  '06:35',
#  '08:45',
#  '15:35',
#  '17:35',
#  '22:50',
#  '22:50',
#  '14:15\n+ 1 day',
#  '22:35',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55\n+ 1 day',
#  '22:55\n+ 1 day',
#  '22:50',
#  '22:50',
#  '22:35',
#  '17:25',
#  '19:10',
#  '15:45',
#  '15:45',
#  '21:50',
#  '21:50',
#  '22:50',
#  '20:25\n+ 1 day',
#  '19:10',
#  '17:25',
#  '15:45',
#  '15:45',
#  '21:50',
#  '21:50',
#  '21:50',
#  '21:50',
#  '21:50',
#  '22:50',
#  '20:15',
#  '20:15',
#  '20:15\n+ 1 day',
#  '17:00\n+ 1 day',
#  '17:00\n+ 1 day',
#  '17:35\n+ 1 day',
#  '22:55',
#  '22:55',
#  '22:55\n+ 1 day',
#  '22:55',
#  '19:10',
#  '22:55\n+ 1 day',
# ...

# %%
len(dname_titels2)
# Out:
# 241

# %%
dname_titels2[:235]
# Out:
# ['21:50',
#  '21:50',
#  '21:50',
#  '18:35',
#  '19:55',
#  '18:35',
#  '19:55',
#  '07:15',
#  '14:05',
#  '17:40',
#  '07:50',
#  '14:05',
#  '17:40',
#  '23:35',
#  '23:35',
#  '23:35',
#  '23:35\n+ 1 day',
#  '12:05',
#  '06:35',
#  '08:45',
#  '15:35',
#  '12:05',
#  '14:15\n+ 1 day',
#  '06:35',
#  '08:45',
#  '15:35',
#  '17:35',
#  '22:50',
#  '22:50',
#  '14:15\n+ 1 day',
#  '22:35',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55',
#  '22:55\n+ 1 day',
#  '22:55\n+ 1 day',
#  '22:50',
#  '22:50',
#  '22:35',
#  '17:25',
#  '19:10',
#  '15:45',
#  '15:45',
#  '21:50',
#  '21:50',
#  '22:50',
#  '20:25\n+ 1 day',
#  '19:10',
#  '17:25',
#  '15:45',
#  '15:45',
#  '21:50',
#  '21:50',
#  '21:50',
#  '21:50',
#  '21:50',
#  '22:50',
#  '20:15',
#  '20:15',
#  '20:15\n+ 1 day',
#  '17:00\n+ 1 day',
#  '17:00\n+ 1 day',
#  '17:35\n+ 1 day',
#  '22:55',
#  '22:55',
#  '22:55\n+ 1 day',
#  '22:55',
#  '19:10',
#  '22:55\n+ 1 day',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fce65d45-9c59-41d5-9380-aacb99b3e493")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="95eceded-bd44-4b72-9da1-02269d94b76a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2af0fa89-2c2f-40e4-9ee5-22872304340c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4dbe5a4e-e8cd-4cc0-aa0b-045654ba843a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2bb1d5a0-94ab-417d-a5d6-da7fcba78be1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3abbbb9c-4abc-4a44-a762-3358bbadeeb0")>,
# ...

# %%
name_titels2=[]
for i in titles_tag:
    name_titels2.append(i.text)
name_titels2
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
# ...

# %%
len(name_titels2)
# Out:
# 241

# %%
name_titels2[:235]
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c5418711-1155-4c7a-a4b8-2da4a742b74d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="105c9812-6f56-43e1-b180-cd6237ec898a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b1bf5978-9451-4e53-b70c-8ea9aea595e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1ae318f8-06cd-4afb-a7ff-14f7dbe87aee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="eeb57ad9-735a-41af-9779-c8fa0d851423")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f90f7c01-91be-42fa-af0b-3d5d24213c51")>,
# ...

# %%
price_titels12=[]
for i in titles_tag:
    price_titels12.append(i.text)
price_titels12
# Out:
# ['4,262',
#  '4,262',
#  '4,262',
#  '4,263',
#  '4,263',
#  '4,657',
#  '4,657',
#  '5,208',
#  '5,681',
#  '5,891',
#  '5,996',
#  '6,074',
#  '6,284',
#  '7,584',
#  '7,584',
#  '7,584',
#  '7,584',
#  '7,886',
#  '8,044',
#  '8,044',
#  '8,044',
#  '8,279',
#  '8,463',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,581',
#  '9,093',
#  '9,093',
#  '9,356',
#  '9,461',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,987',
#  '9,987',
#  '10,353',
#  '10,427',
#  '10,721',
#  '10,931',
#  '10,931',
#  '11,377',
#  '11,377',
#  '11,403',
#  '11,475',
#  '11,613',
#  '11,687',
#  '11,823',
#  '11,823',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,297',
#  '13,086',
#  '13,086',
#  '13,086',
#  '13,608',
#  '13,608',
#  '13,687',
#  '14,079',
#  '14,143',
#  '14,573',
#  '15,413',
#  '15,761',
#  '15,938',
#  '15,971',
#  '16,154',
#  '16,364',
#  '16,654',
#  '16,654',
#  '16,694',
# ...

# %%
len(price_titels12)
# Out:
# 239

# %%
price_titels12[:235]
# Out:
# ['4,262',
#  '4,262',
#  '4,262',
#  '4,263',
#  '4,263',
#  '4,657',
#  '4,657',
#  '5,208',
#  '5,681',
#  '5,891',
#  '5,996',
#  '6,074',
#  '6,284',
#  '7,584',
#  '7,584',
#  '7,584',
#  '7,584',
#  '7,886',
#  '8,044',
#  '8,044',
#  '8,044',
#  '8,279',
#  '8,463',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,581',
#  '9,093',
#  '9,093',
#  '9,356',
#  '9,461',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,987',
#  '9,987',
#  '10,353',
#  '10,427',
#  '10,721',
#  '10,931',
#  '10,931',
#  '11,377',
#  '11,377',
#  '11,403',
#  '11,475',
#  '11,613',
#  '11,687',
#  '11,823',
#  '11,823',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,269',
#  '12,297',
#  '13,086',
#  '13,086',
#  '13,086',
#  '13,608',
#  '13,608',
#  '13,687',
#  '14,079',
#  '14,143',
#  '14,573',
#  '15,413',
#  '15,761',
#  '15,938',
#  '15,971',
#  '16,154',
#  '16,364',
#  '16,654',
#  '16,654',
#  '16,694',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="77ad7aff-5d7f-4278-9011-78369f30e7ce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fa98017b-d99f-4c6d-87e8-9ab3179d62b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="dab3666d-0ccb-4d5a-b775-a89b60a16fca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6cd1de5d-81fa-4cb0-a6b9-d5115f13127a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3a01ddf0-bdb6-4462-8131-465dc4b3eb50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="5284d26f-59bc-4b6f-9cbe-ff67d560c2d0")>,
# ...

# %%
price_titels2=[]
for i in titles_tag:
    price_titels2.append(i.text)
price_titels2
# Out:
# ['Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
# ...

# %%
NAME2= []
for i in range(1,len(price_titels2),2):
    NAME2.append(price_titels2[i])
NAME2
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
NAME2[:235]
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
NAME4= []
for i in range(2,len(price_titels2),2):
    NAME4.append(price_titels2[i])
NAME4
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
NAME4[:235]
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels1[:200]
copy['flight id']=name_titels[:200]
copy['price']=price_titels2[:200]
copy['arrival time']=sname_titels2[:200]
copy['departure time']=dname_titels2[:200]
copy['hours taken']=name_titels[:200]
copy['starting point']=NAME2[:200]
copy['destination']=NAME1[:200]

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels2[:235]+name_titels1[:200]
copy['id']=name_titels0[:235]+name_titels[:200]
copy['price']=price_titels12[:235]+price_titels2[:200]
copy['arrival time']=sname_titels2[:235]+sname_titels2[:200]
copy['departure time']=dname_titels2[:235]+dname_titels2[:200]
copy['hours taken']=name_titels12[:235]+name_titels[:200]
copy['starting point']=NAME4[:235]+NAME2[:200]
copy['destination']=NAME2[:235]+NAME1[:200]

# %%
copy
# Out:
#          Name          id      price arrival time departure time hours taken  \
# 0    Go First  G8-391/422      4,262        13:30          21:50      8h 20m
# 1    Go First  G8-321/422      4,262        12:15          21:50      9h 35m
# 2    Go First  G8-319/422      4,262        09:55          21:50     11h 55m
# 3      IndiGo     6E-5208      4,263        17:10          18:35      1h 25m
# 4      IndiGo     6E-6818      4,263        18:30          19:55      1h 25m
# ..        ...         ...        ...          ...            ...         ...
# 430   Vistara              Hyderabad        07:40
# 431  Go First                 Mumbai        20:45
# 432  Go First              Hyderabad        20:45
# 433   Vistara              Hyderabad        07:40
# 434   Vistara                               07:40
#
#     starting point destination
# 0           Mumbai   Hyderabad
# 1           Mumbai   Hyderabad
# 2           Mumbai   Hyderabad
# 3           Mumbai   Hyderabad
# ...

# %%
copy.to_csv('flight121.csv')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=M&viewName=normal&flexi=0&noOfSegments=2&origin_0=DEL&destination_0=BOM&originCountry_0=IN&destinationCountry_0=IN&flight_depart_date_0=05%2F11%2F2021&origin_1=BOM&destination_1=DEL&originCountry_1=IN&destinationCountry_1=IN&flight_depart_date_1=05%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=631363195858'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="55b50a2d-05c4-4200-a03b-b3fbcf114d00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="54d440d1-3223-4d84-ab27-e6c96322d9b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="487b8592-a60d-4b5e-8d2e-4d887463d039")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="128d5422-b643-4fb0-b3b6-2fcf4ceda1fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8360b4b1-3032-4b15-81d4-7cdc64ab6e65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3403500d-8759-4149-a39d-84e2ece00f02")>,
# ...

# %%
name_titels=[]
for i in titles_tag:
    name_titels.append(i.text)
name_titels
# Out:
# ['G8-530',
#  'G8-334',
#  'G8-354',
#  'G8-2501',
#  'G8-336',
#  'G8-392',
#  'G8-346',
#  'G8-330',
#  'G8-338',
#  'G8-323',
#  'G8-188/396',
#  'G8-131/352',
#  'G8-211/307',
#  'G8-143/352',
#  'G8-404/350',
#  'G8-237/388',
#  'UK-975',
#  'AI-887',
#  'UK-927',
#  '6E-2054',
#  '6E-5001',
#  'AI-665',
#  '6E-5329',
#  'AI-865',
#  '6E-6202',
#  'UK-993',
#  'UK-933',
#  'UK-941',
#  '6E-2046',
#  'AI-868',
#  'SG-8709',
#  'UK-985',
#  'AI-805',
#  'UK-953',
#  'UK-981',
#  '6E-2519',
#  '6E-171',
#  'SG-8701',
#  'UK-943',
#  'AI-678',
#  '6E-5328',
#  'UK-995',
#  '6E-2176',
#  '6E-573',
#  '6E-5041',
#  'AI-624',
#  '6E-6261',
#  '6E-6722',
#  'SG-8157',
#  '6E-6278',
#  'UK-963',
#  '6E-218',
#  'UK-945',
#  'UK-955',
#  'UK-977',
#  'SG-8169',
#  '6E-2081',
#  'AI-636',
#  'SG-3001',
#  'AI-441',
#  'SG-2976/4418',
#  'SG-2976/279',
#  'I5-764',
#  'I5-482',
#  'I5-764',
#  'I5-482',
#  '6E-2054',
#  '6E-5001',
#  '6E-5329',
#  '6E-6202',
#  '6E-2046',
#  '6E-2519',
# ...

# %%
len(name_titels)
# Out:
# 503

# %%
name_titels[:500]
# Out:
# ['G8-530',
#  'G8-334',
#  'G8-354',
#  'G8-2501',
#  'G8-336',
#  'G8-392',
#  'G8-346',
#  'G8-330',
#  'G8-338',
#  'G8-323',
#  'G8-188/396',
#  'G8-131/352',
#  'G8-211/307',
#  'G8-143/352',
#  'G8-404/350',
#  'G8-237/388',
#  'UK-975',
#  'AI-887',
#  'UK-927',
#  '6E-2054',
#  '6E-5001',
#  'AI-665',
#  '6E-5329',
#  'AI-865',
#  '6E-6202',
#  'UK-993',
#  'UK-933',
#  'UK-941',
#  '6E-2046',
#  'AI-868',
#  'SG-8709',
#  'UK-985',
#  'AI-805',
#  'UK-953',
#  'UK-981',
#  '6E-2519',
#  '6E-171',
#  'SG-8701',
#  'UK-943',
#  'AI-678',
#  '6E-5328',
#  'UK-995',
#  '6E-2176',
#  '6E-573',
#  '6E-5041',
#  'AI-624',
#  '6E-6261',
#  '6E-6722',
#  'SG-8157',
#  '6E-6278',
#  'UK-963',
#  '6E-218',
#  'UK-945',
#  'UK-955',
#  'UK-977',
#  'SG-8169',
#  '6E-2081',
#  'AI-636',
#  'SG-3001',
#  'AI-441',
#  'SG-2976/4418',
#  'SG-2976/279',
#  'I5-764',
#  'I5-482',
#  'I5-764',
#  'I5-482',
#  '6E-2054',
#  '6E-5001',
#  '6E-5329',
#  '6E-6202',
#  '6E-2046',
#  '6E-2519',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3dab30c8-ab47-4693-9dd6-171dce1d112d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8fb7aa2e-b705-47d0-b780-3931a94c6002")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a18aa5f8-7b57-4a91-b761-09615a69b007")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2b5466a9-bb84-4085-9f2b-3447015f0236")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="95aa36b4-c0e1-463d-b66b-8340b70cf238")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="cf30e797-747b-48cd-87dc-8e17472fcb3b")>,
# ...

# %%
name_titels12=[]
for i in titles_tag:
    name_titels12.append(i.text)
name_titels12
# Out:
# ['2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '4h 40m',
#  '5h 30m',
#  '6h 45m',
#  '8h 00m',
#  '8h 05m',
#  '9h 15m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 25m',
#  '3h 10m',
#  '3h 40m',
#  '3h 45m',
#  '4h 50m',
#  '15h 35m',
#  '2h 10m',
#  '2h 15m',
#  '2h 10m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
# ...

# %%
len(name_titels12)
# Out:
# 503

# %%
name_titels12[:500]
# Out:
# ['2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '4h 40m',
#  '5h 30m',
#  '6h 45m',
#  '8h 00m',
#  '8h 05m',
#  '9h 15m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '2h 25m',
#  '3h 10m',
#  '3h 40m',
#  '3h 45m',
#  '4h 50m',
#  '15h 35m',
#  '2h 10m',
#  '2h 15m',
#  '2h 10m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b pr']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="e1bae76d-3d5a-4f9c-bfae-cbd5e732241a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3bcf946f-f3e8-44e4-800f-3640142f813a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1ed3e9df-3d31-449a-a2b0-26f9b3a8fe1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="979044d8-bab9-437c-8b1d-83adbbd995b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1d239e51-db08-4baf-a93a-2ae4435e3b37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="699ad04f-8e66-47c3-8836-4ca1735d7d10")>,
# ...

# %%
sname_titels2=[]
for i in titles_tag:
    sname_titels2.append(i.text)
sname_titels2
# Out:
# ['07:00',
#  '08:00',
#  '22:30',
#  '02:00',
#  '14:20',
#  '14:45',
#  '20:10',
#  '21:00',
#  '10:30',
#  '18:05',
#  '18:10',
#  '11:30',
#  '09:00',
#  '09:00',
#  '09:10',
#  '12:50',
#  '06:00',
#  '07:00',
#  '09:30',
#  '06:30',
#  '07:15',
#  '08:00',
#  '08:10',
#  '10:40',
#  '12:00',
#  '12:50',
#  '15:30',
#  '16:55',
#  '17:15',
#  '17:50',
#  '18:55',
#  '19:50',
#  '20:00',
#  '20:40',
#  '21:40',
#  '23:15',
#  '01:05',
#  '07:20',
#  '07:30',
#  '09:00',
#  '09:30',
#  '10:20',
#  '14:20',
#  '16:00',
#  '18:35',
#  '19:00',
#  '20:00',
#  '21:15',
#  '06:20',
#  '08:45',
#  '08:50',
#  '10:45',
#  '11:40',
#  '17:45',
#  '18:55',
#  '19:45',
#  '04:45',
#  '15:05',
#  '06:35',
#  '17:50',
#  '19:00',
#  '19:00',
#  '04:25',
#  '20:00',
#  '04:25',
#  '20:00',
#  '06:30',
#  '07:15',
#  '08:10',
#  '12:00',
#  '17:15',
#  '23:15',
#  '01:05',
#  '09:30',
#  '14:20',
#  '16:00',
#  '18:35',
#  '20:00',
#  '21:15',
#  '08:45',
#  '10:45',
#  '04:45',
#  '15:00',
# ...

# %%
len(sname_titels2)
# Out:
# 503

# %%
sname_titels2[:500]
# Out:
# ['07:00',
#  '08:00',
#  '22:30',
#  '02:00',
#  '14:20',
#  '14:45',
#  '20:10',
#  '21:00',
#  '10:30',
#  '18:05',
#  '18:10',
#  '11:30',
#  '09:00',
#  '09:00',
#  '09:10',
#  '12:50',
#  '06:00',
#  '07:00',
#  '09:30',
#  '06:30',
#  '07:15',
#  '08:00',
#  '08:10',
#  '10:40',
#  '12:00',
#  '12:50',
#  '15:30',
#  '16:55',
#  '17:15',
#  '17:50',
#  '18:55',
#  '19:50',
#  '20:00',
#  '20:40',
#  '21:40',
#  '23:15',
#  '01:05',
#  '07:20',
#  '07:30',
#  '09:00',
#  '09:30',
#  '10:20',
#  '14:20',
#  '16:00',
#  '18:35',
#  '19:00',
#  '20:00',
#  '21:15',
#  '06:20',
#  '08:45',
#  '08:50',
#  '10:45',
#  '11:40',
#  '17:45',
#  '18:55',
#  '19:45',
#  '04:45',
#  '15:05',
#  '06:35',
#  '17:50',
#  '19:00',
#  '19:00',
#  '04:25',
#  '20:00',
#  '04:25',
#  '20:00',
#  '06:30',
#  '07:15',
#  '08:10',
#  '12:00',
#  '17:15',
#  '23:15',
#  '01:05',
#  '09:30',
#  '14:20',
#  '16:00',
#  '18:35',
#  '20:00',
#  '21:15',
#  '08:45',
#  '10:45',
#  '04:45',
#  '15:00',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="679e1319-78d4-4548-910c-90f9fecd4bdb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="01e666b6-b348-4ca9-bb2f-10a5d0116b36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c49d14ea-959d-4f7d-a663-d175ee5dc6ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8e2edd54-3f28-4f7f-aa68-a56583d578bc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="42c13b2f-965d-4a36-a029-7496d9668310")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="0712eb42-7115-439f-89d4-b6ae8b488190")>,
# ...

# %%
dname_titels2=[]
for i in titles_tag:
    dname_titels2.append(i.text)
dname_titels2
# Out:
# ['09:10',
#  '10:10',
#  '00:40\n+ 1 day',
#  '04:15',
#  '16:35',
#  '17:00',
#  '22:25',
#  '23:15',
#  '12:50',
#  '20:25',
#  '22:50',
#  '17:00',
#  '15:45',
#  '17:00',
#  '17:15',
#  '22:05',
#  '08:00',
#  '09:05',
#  '11:35',
#  '08:40',
#  '09:25',
#  '10:10',
#  '10:20',
#  '12:50',
#  '14:10',
#  '15:00',
#  '17:40',
#  '19:05',
#  '19:25',
#  '20:00',
#  '21:05',
#  '22:00',
#  '22:10',
#  '22:50',
#  '23:50',
#  '01:25\n+ 1 day',
#  '03:20',
#  '09:35',
#  '09:45',
#  '11:15',
#  '11:45',
#  '12:35',
#  '16:35',
#  '18:15',
#  '20:50',
#  '21:15',
#  '22:15',
#  '23:30',
#  '08:40',
#  '11:05',
#  '11:10',
#  '13:05',
#  '14:00',
#  '20:05',
#  '21:15',
#  '22:05',
#  '07:10',
#  '18:15',
#  '10:15',
#  '21:35',
#  '23:50',
#  '10:35\n+ 1 day',
#  '06:35',
#  '22:15',
#  '06:35',
#  '22:15',
#  '08:40',
#  '09:25',
#  '10:20',
#  '14:10',
#  '19:25',
#  '01:25\n+ 1 day',
#  '03:20',
#  '11:45',
#  '16:35',
#  '18:15',
#  '20:50',
#  '22:15',
#  '23:30',
#  '11:05',
# ...

# %%
len(dname_titels2)
# Out:
# 503

# %%
dname_titels2[:500]
# Out:
# ['09:10',
#  '10:10',
#  '00:40\n+ 1 day',
#  '04:15',
#  '16:35',
#  '17:00',
#  '22:25',
#  '23:15',
#  '12:50',
#  '20:25',
#  '22:50',
#  '17:00',
#  '15:45',
#  '17:00',
#  '17:15',
#  '22:05',
#  '08:00',
#  '09:05',
#  '11:35',
#  '08:40',
#  '09:25',
#  '10:10',
#  '10:20',
#  '12:50',
#  '14:10',
#  '15:00',
#  '17:40',
#  '19:05',
#  '19:25',
#  '20:00',
#  '21:05',
#  '22:00',
#  '22:10',
#  '22:50',
#  '23:50',
#  '01:25\n+ 1 day',
#  '03:20',
#  '09:35',
#  '09:45',
#  '11:15',
#  '11:45',
#  '12:35',
#  '16:35',
#  '18:15',
#  '20:50',
#  '21:15',
#  '22:15',
#  '23:30',
#  '08:40',
#  '11:05',
#  '11:10',
#  '13:05',
#  '14:00',
#  '20:05',
#  '21:15',
#  '22:05',
#  '07:10',
#  '18:15',
#  '10:15',
#  '21:35',
#  '23:50',
#  '10:35\n+ 1 day',
#  '06:35',
#  '22:15',
#  '06:35',
#  '22:15',
#  '08:40',
#  '09:25',
#  '10:20',
#  '14:10',
#  '19:25',
#  '01:25\n+ 1 day',
#  '03:20',
#  '11:45',
#  '16:35',
#  '18:15',
#  '20:50',
#  '22:15',
#  '23:30',
#  '11:05',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="5e11c593-dd94-427b-9d12-b123d4dee776")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4fb3c2fc-15c9-4979-801d-02a8feb52219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6c8816b9-89db-4b01-9d45-b347327dcce3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="46260154-0c0b-42a0-8c18-c62a6e552b75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="5e256846-dc71-4e73-b557-2d69aaaac73a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c6d53215-5d85-4f7b-867e-07142d2a4264")>,
# ...

# %%
name_titels2=[]
for i in titles_tag:
    name_titels2.append(i.text)
name_titels2
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
len(name_titels2)
# Out:
# 503

# %%
name_titels2[:500]
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="c0a04181-67ab-4334-a222-9593a8b6f862")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f91919d7-93cd-430a-af74-efe53372da0b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="4bd7b940-7186-44d2-8a35-af7863ef6f1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="fed26699-caae-4e0a-baff-06a041b9dadf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="09854746-4770-42f9-9bab-b735091fdf44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6d595ee3-913d-4a3f-8339-f9ee73b1a61c")>,
# ...

# %%
price_titels12=[]
for i in titles_tag:
    price_titels12.append(i.text)
price_titels12
# Out:
# ['5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '5,956',
#  '6,060',
#  '6,060',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,271',
# ...

# %%
len(price_titels12)
# Out:
# 501

# %%
price_titels12[:500]
# Out:
# ['5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '5,956',
#  '6,060',
#  '6,060',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,271',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="f4f5be0e-908e-4b3b-aec4-65e811998910")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8fbc59e0-f505-46af-959c-21442afa04d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="05c39a60-d6e6-4129-8e09-9b32a9d16bc7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b6f2f6c0-825c-4660-a78b-64a7f861a042")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d05b1baf-958e-4775-8d97-8486d1e6b8ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="5b068fc4-4016-4472-a8a1-45b6fb3b2bd7")>,
# ...

# %%
price_titels2=[]
for i in titles_tag:
    price_titels2.append(i.text)
price_titels2
# Out:
# ['New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
# ...

# %%
NAME2= []
for i in range(1,len(price_titels2),2):
    NAME2.append(price_titels2[i])
NAME2
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
NAME2[:500]
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
NAME4= []
for i in range(2,len(price_titels2),2):
    NAME4.append(price_titels2[i])
NAME4
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
NAME4[:500]
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels2[:235]+name_titels1[:200]
copy['id']=name_titels0[:235]+name_titels[:200]
copy['price']=price_titels12[:235]+price_titels2[:200]
copy['arrival time']=sname_titels2[:235]+sname_titels2[:200]
copy['departure time']=dname_titels2[:235]+dname_titels2[:200]
copy['hours taken']=name_titels12[:235]+name_titels[:200]
copy['starting point']=NAME4[:235]+NAME2[:200]
copy['destination']=NAME2[:235]+NAME1[:200]

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels2[:500]+name_titels2[:235]
copy['id']=name_titels[:500]+name_titels0[:235]
copy['price']=price_titels12[:500]+price_titels12[:235]
copy['arrival time']=sname_titels2[:500]+sname_titels2[:235]
copy['departure time']=dname_titels2[:500]+dname_titels2[:235]
copy['hours taken']=name_titels12[:500]+name_titels12[:235]
copy['starting point']=NAME4[:500]+NAME4[:235]
copy['destination']=NAME2[:500]+NAME2[:235]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-328-4fcf5a291321> in <module>
#       2 copy=pd.DataFrame({})
#       3 copy['Name']=name_titels2[:500]+name_titels2[:235]
# ----> 4 copy['id']=name_titels[:500]+name_titels0[:235]
#       5 copy['price']=price_titels12[:500]+price_titels12[:235]
#       6 copy['arrival time']=sname_titels2[:500]+sname_titels2[:235]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
# ...

# %%
copy
# Out:
#          Name          id      price arrival time  departure time hours taken  \
# 0    Go First      G8-530      5,954        07:00           09:10      2h 10m
# 1    Go First      G8-334      5,954        08:00           10:10      2h 10m
# 2    Go First      G8-354      5,954        22:30  00:40\n+ 1 day      2h 10m
# 3    Go First     G8-2501      5,954        02:00           04:15      2h 15m
# 4    Go First      G8-336      5,954        14:20           16:35      2h 15m
# ..        ...         ...        ...          ...             ...         ...
# 930   Vistara  UK-899/878     Mumbai        14:45  14:30\n+ 1 day  UK-899/878
# 931  Go First  AI-451/651  New Delhi        14:30  16:25\n+ 1 day  AI-451/651
# 932  Go First  G8-131/352     Mumbai        11:30           17:00  G8-131/352
# 933   Vistara  G8-143/352  New Delhi        09:00           17:00  G8-143/352
# 934   Vistara  G8-188/396     Mumbai        18:10           22:50  G8-188/396
#
#     starting point destination
# ...

# %%
copy.to_csv('flight151.csv')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=M&viewName=normal&flexi=0&noOfSegments=2&origin_0=DEL&destination_0=PNQ&originCountry_0=IN&destinationCountry_0=IN&flight_depart_date_0=05%2F11%2F2021&origin_1=PNQ&destination_1=HYD&originCountry_1=IN&destinationCountry_1=IN&flight_depart_date_1=05%2F11%2F2021&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1310661501869'
driver.get(url)

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='normal fs-11 font-lightestgrey no-wrap fl-no']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1dbabec5-0535-4a46-8cf2-f0193f808f58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8f27dbc9-3b27-413e-8b0f-b8764046dc13")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3bcb4ce1-30f6-4b21-bd9d-16ba7bba8014")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b69e7417-ef54-4925-89ed-ad93b6e90b27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2d2eaf73-ff9e-4f6f-b9be-3d2fd06f0f40")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6c5d6199-78ea-49ce-ab77-ddf3579eefb7")>,
# ...

# %%
name_titels=[]
for i in titles_tag:
    name_titels.append(i.text)
name_titels
# Out:
# ['G8-2513',
#  'G8-173',
#  'SG-8185',
#  'SG-8938',
#  'G8-1171',
#  'G8-101/393',
#  'G8-404/241',
#  'G8-404/753',
#  'G8-113/241',
#  'G8-145/241',
#  'G8-113/753',
#  'G8-145/753',
#  'G8-119/283',
#  '6E-788',
#  'AI-851',
#  '6E-2769',
#  '6E-2351',
#  'UK-931',
#  '6E-286',
#  'UK-971',
#  'UK-991',
#  'UK-973',
#  '6E-2005/311',
#  '6E-2247/118',
#  '6E-5012/401',
#  '6E-2005/118',
#  '6E-552/311',
#  '6E-6231/147',
#  '6E-2331/311',
#  '6E-198/217',
#  '6E-552/118',
#  '6E-198/522',
#  '6E-5012/105',
#  '6E-2331/118',
#  '6E-2478/6483',
#  '6E-2061/502',
#  'I5-768',
#  'I5-784',
#  'I5-740/1426',
#  'I5-768',
#  'I5-784',
#  '6E-788',
#  '6E-2769',
#  '6E-2351',
#  '6E-286',
#  'G8-2513',
#  'G8-173',
#  'G8-1171',
#  '6E-6238/105',
#  'I5-740/1426',
#  '6E-2005/311',
#  '6E-2247/118',
#  '6E-5012/401',
#  '6E-2005/118',
#  '6E-552/311',
#  '6E-6231/147',
#  '6E-2331/311',
#  '6E-198/217',
#  '6E-552/118',
#  '6E-198/522',
#  '6E-5012/105',
#  '6E-2331/118',
# ...

# %%
len(name_titels)
# Out:
# 206

# %%
name_titels[:200]
# Out:
# ['G8-2513',
#  'G8-173',
#  'SG-8185',
#  'SG-8938',
#  'G8-1171',
#  'G8-101/393',
#  'G8-404/241',
#  'G8-404/753',
#  'G8-113/241',
#  'G8-145/241',
#  'G8-113/753',
#  'G8-145/753',
#  'G8-119/283',
#  '6E-788',
#  'AI-851',
#  '6E-2769',
#  '6E-2351',
#  'UK-931',
#  '6E-286',
#  'UK-971',
#  'UK-991',
#  'UK-973',
#  '6E-2005/311',
#  '6E-2247/118',
#  '6E-5012/401',
#  '6E-2005/118',
#  '6E-552/311',
#  '6E-6231/147',
#  '6E-2331/311',
#  '6E-198/217',
#  '6E-552/118',
#  '6E-198/522',
#  '6E-5012/105',
#  '6E-2331/118',
#  '6E-2478/6483',
#  '6E-2061/502',
#  'I5-768',
#  'I5-784',
#  'I5-740/1426',
#  'I5-768',
#  'I5-784',
#  '6E-788',
#  '6E-2769',
#  '6E-2351',
#  '6E-286',
#  'G8-2513',
#  'G8-173',
#  'G8-1171',
#  '6E-6238/105',
#  'I5-740/1426',
#  '6E-2005/311',
#  '6E-2247/118',
#  '6E-5012/401',
#  '6E-2005/118',
#  '6E-552/311',
#  '6E-6231/147',
#  '6E-2331/311',
#  '6E-198/217',
#  '6E-552/118',
#  '6E-198/522',
#  '6E-5012/105',
#  '6E-2331/118',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="62d6eba7-b1e9-403f-b97a-39a32f39a1b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d6f92165-b7f0-42f7-89b7-ef2232ce806b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="aece0b8d-d58c-4dc5-8ce6-f039dce54491")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2661009f-4f89-4637-9d44-75c526160e74")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="68124ebc-fb2f-4883-b80a-3e04e10c9de4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="025abb1e-cedc-47f5-b406-16bea9f9bfab")>,
# ...

# %%
name_titels12=[]
for i in titles_tag:
    name_titels12.append(i.text)
name_titels12
# Out:
# ['2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '8h 30m',
#  '9h 05m',
#  '9h 50m',
#  '12h 10m',
#  '12h 40m',
#  '12h 55m',
#  '13h 25m',
#  '13h 50m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '5h 25m',
#  '5h 45m',
#  '6h 00m',
#  '7h 05m',
#  '7h 10m',
#  '7h 40m',
#  '8h 20m',
#  '8h 50m',
#  '8h 50m',
#  '9h 25m',
#  '9h 50m',
#  '10h 00m',
#  '10h 15m',
#  '10h 55m',
#  '1h 55m',
#  '2h 00m',
#  '6h 25m',
#  '1h 55m',
#  '2h 00m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 15m',
#  '8h 40m',
#  '6h 25m',
#  '5h 25m',
#  '5h 45m',
#  '6h 00m',
#  '7h 05m',
#  '7h 10m',
#  '7h 40m',
#  '8h 20m',
#  '8h 50m',
#  '8h 50m',
#  '9h 25m',
#  '9h 50m',
#  '10h 00m',
#  '10h 15m',
#  '10h 55m',
#  '2h 10m',
#  '2h 10m',
#  '8h 40m',
#  '3h 25m',
#  '8h 55m',
#  '8h 55m',
#  '6h 10m',
#  '8h 15m',
#  '6h 10m',
#  '8h 15m',
#  '2h 05m',
#  '2h 10m',
# ...

# %%
len(name_titels12)
# Out:
# 206

# %%
name_titels12[:200]
# Out:
# ['2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '8h 30m',
#  '9h 05m',
#  '9h 50m',
#  '12h 10m',
#  '12h 40m',
#  '12h 55m',
#  '13h 25m',
#  '13h 50m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '5h 25m',
#  '5h 45m',
#  '6h 00m',
#  '7h 05m',
#  '7h 10m',
#  '7h 40m',
#  '8h 20m',
#  '8h 50m',
#  '8h 50m',
#  '9h 25m',
#  '9h 50m',
#  '10h 00m',
#  '10h 15m',
#  '10h 55m',
#  '1h 55m',
#  '2h 00m',
#  '6h 25m',
#  '1h 55m',
#  '2h 00m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 15m',
#  '8h 40m',
#  '6h 25m',
#  '5h 25m',
#  '5h 45m',
#  '6h 00m',
#  '7h 05m',
#  '7h 10m',
#  '7h 40m',
#  '8h 20m',
#  '8h 50m',
#  '8h 50m',
#  '9h 25m',
#  '9h 50m',
#  '10h 00m',
#  '10h 15m',
#  '10h 55m',
#  '2h 10m',
#  '2h 10m',
#  '8h 40m',
#  '3h 25m',
#  '8h 55m',
#  '8h 55m',
#  '6h 10m',
#  '8h 15m',
#  '6h 10m',
#  '8h 15m',
#  '2h 05m',
#  '2h 10m',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b pr']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="aaf12140-1875-4b8c-ab7b-64f2050caa69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d6590b9f-e380-4c11-b532-65f6c82ae70d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1072def4-5205-40eb-b330-a9ceb809b390")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="52a6206c-07ac-43c0-aad6-0c99645e7438")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="a0b049cd-d376-4fc0-ad10-d7a1402be4b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="951e1bd6-0d86-4dde-8b99-a970c17bce00")>,
# ...

# %%
sname_titels2=[]
for i in titles_tag:
    sname_titels2.append(i.text)
sname_titels2
# Out:
# ['16:35',
#  '08:35',
#  '08:40',
#  '17:45',
#  '12:45',
#  '05:50',
#  '09:10',
#  '09:10',
#  '06:05',
#  '05:35',
#  '06:05',
#  '05:35',
#  '18:40',
#  '13:40',
#  '06:00',
#  '08:25',
#  '11:10',
#  '14:15',
#  '16:40',
#  '10:25',
#  '16:20',
#  '17:25',
#  '09:40',
#  '11:00',
#  '07:25',
#  '09:40',
#  '07:55',
#  '05:30',
#  '06:45',
#  '05:15',
#  '07:55',
#  '05:15',
#  '07:25',
#  '06:45',
#  '23:05',
#  '23:05',
#  '15:25',
#  '16:05',
#  '08:00',
#  '15:25',
#  '16:05',
#  '13:40',
#  '08:25',
#  '11:10',
#  '16:40',
#  '16:35',
#  '08:35',
#  '12:45',
#  '08:35',
#  '08:00',
#  '09:40',
#  '11:00',
#  '07:25',
#  '09:40',
#  '07:55',
#  '05:30',
#  '06:45',
#  '05:15',
#  '07:55',
#  '05:15',
#  '07:25',
#  '06:45',
#  '23:05',
#  '23:05',
#  '08:40',
#  '17:45',
#  '08:35',
#  '08:40',
#  '08:30',
#  '08:30',
#  '13:30',
#  '11:25',
#  '13:30',
#  '11:25',
#  '16:35',
#  '08:35',
#  '12:45',
#  '20:10',
#  '19:10',
#  '16:45',
#  '06:05',
#  '06:05',
#  '18:40',
# ...

# %%
len(sname_titels2)
# Out:
# 206

# %%
sname_titels2[:200]
# Out:
# ['16:35',
#  '08:35',
#  '08:40',
#  '17:45',
#  '12:45',
#  '05:50',
#  '09:10',
#  '09:10',
#  '06:05',
#  '05:35',
#  '06:05',
#  '05:35',
#  '18:40',
#  '13:40',
#  '06:00',
#  '08:25',
#  '11:10',
#  '14:15',
#  '16:40',
#  '10:25',
#  '16:20',
#  '17:25',
#  '09:40',
#  '11:00',
#  '07:25',
#  '09:40',
#  '07:55',
#  '05:30',
#  '06:45',
#  '05:15',
#  '07:55',
#  '05:15',
#  '07:25',
#  '06:45',
#  '23:05',
#  '23:05',
#  '15:25',
#  '16:05',
#  '08:00',
#  '15:25',
#  '16:05',
#  '13:40',
#  '08:25',
#  '11:10',
#  '16:40',
#  '16:35',
#  '08:35',
#  '12:45',
#  '08:35',
#  '08:00',
#  '09:40',
#  '11:00',
#  '07:25',
#  '09:40',
#  '07:55',
#  '05:30',
#  '06:45',
#  '05:15',
#  '07:55',
#  '05:15',
#  '07:25',
#  '06:45',
#  '23:05',
#  '23:05',
#  '08:40',
#  '17:45',
#  '08:35',
#  '08:40',
#  '08:30',
#  '08:30',
#  '13:30',
#  '11:25',
#  '13:30',
#  '11:25',
#  '16:35',
#  '08:35',
#  '12:45',
#  '20:10',
#  '19:10',
#  '16:45',
#  '06:05',
#  '06:05',
#  '18:40',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6d6a21ff-4dd2-45b9-8b89-f43302634b4e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="88026ce9-d631-4ce1-a05d-0411b4b5edb5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8911dd85-513e-418d-91c0-2ae0fae405fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="80ab9023-f788-446e-8fe6-38dbff040317")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="afffb24b-6314-431a-bad9-3aa3a256c2bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="41429993-c4d3-496e-acc9-a38daad8b58e")>,
# ...

# %%
dname_titels2=[]
for i in titles_tag:
    dname_titels2.append(i.text)
dname_titels2
# Out:
# ['18:40',
#  '10:45',
#  '10:50',
#  '19:55',
#  '15:00',
#  '14:20',
#  '18:15',
#  '19:00',
#  '18:15',
#  '18:15',
#  '19:00',
#  '19:00',
#  '08:30\n+ 1 day',
#  '15:40',
#  '08:05',
#  '10:30',
#  '13:15',
#  '16:20',
#  '18:45',
#  '12:35',
#  '18:35',
#  '19:40',
#  '15:05',
#  '16:45',
#  '13:25',
#  '16:45',
#  '15:05',
#  '13:10',
#  '15:05',
#  '14:05',
#  '16:45',
#  '14:40',
#  '17:15',
#  '16:45',
#  '09:20\n+ 1 day',
#  '10:00\n+ 1 day',
#  '17:20',
#  '18:05',
#  '14:25',
#  '17:20',
#  '18:05',
#  '15:40',
#  '10:30',
#  '13:15',
#  '18:45',
#  '18:40',
#  '10:45',
#  '15:00',
#  '17:15',
#  '14:25',
#  '15:05',
#  '16:45',
#  '13:25',
#  '16:45',
#  '15:05',
#  '13:10',
#  '15:05',
#  '14:05',
#  '16:45',
#  '14:40',
#  '17:15',
#  '16:45',
#  '09:20\n+ 1 day',
#  '10:00\n+ 1 day',
#  '10:50',
#  '19:55',
#  '17:15',
#  '12:05',
#  '17:25',
#  '17:25',
#  '19:40',
#  '19:40',
#  '19:40',
#  '19:40',
#  '18:40',
#  '10:45',
#  '15:00',
#  '08:15\n+ 1 day',
# ...

# %%
len(dname_titels2)
# Out:
# 206

# %%
dname_titels2[:200]
# Out:
# ['18:40',
#  '10:45',
#  '10:50',
#  '19:55',
#  '15:00',
#  '14:20',
#  '18:15',
#  '19:00',
#  '18:15',
#  '18:15',
#  '19:00',
#  '19:00',
#  '08:30\n+ 1 day',
#  '15:40',
#  '08:05',
#  '10:30',
#  '13:15',
#  '16:20',
#  '18:45',
#  '12:35',
#  '18:35',
#  '19:40',
#  '15:05',
#  '16:45',
#  '13:25',
#  '16:45',
#  '15:05',
#  '13:10',
#  '15:05',
#  '14:05',
#  '16:45',
#  '14:40',
#  '17:15',
#  '16:45',
#  '09:20\n+ 1 day',
#  '10:00\n+ 1 day',
#  '17:20',
#  '18:05',
#  '14:25',
#  '17:20',
#  '18:05',
#  '15:40',
#  '10:30',
#  '13:15',
#  '18:45',
#  '18:40',
#  '10:45',
#  '15:00',
#  '17:15',
#  '14:25',
#  '15:05',
#  '16:45',
#  '13:25',
#  '16:45',
#  '15:05',
#  '13:10',
#  '15:05',
#  '14:05',
#  '16:45',
#  '14:40',
#  '17:15',
#  '16:45',
#  '09:20\n+ 1 day',
#  '10:00\n+ 1 day',
#  '10:50',
#  '19:55',
#  '17:15',
#  '12:05',
#  '17:25',
#  '17:25',
#  '19:40',
#  '19:40',
#  '19:40',
#  '19:40',
#  '18:40',
#  '10:45',
#  '15:00',
#  '08:15\n+ 1 day',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="ea9ada4d-b2d5-4b5f-b3df-4f97bf2fa232")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="44305a4b-408b-45fc-ac57-b006fdbabf07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="934ba731-f436-4fb6-87b3-accfa58473c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="45df9487-80ae-4822-aeb9-64af49b970b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8115fe26-7e86-4f67-93e8-31c0bbc2c03a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="6a11396e-553f-40ad-9b87-44d7a27e3ade")>,
# ...

# %%
name_titels2=[]
for i in titles_tag:
    name_titels2.append(i.text)
name_titels2
# Out:
# ['Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
len(name_titels2)
# Out:
# 206

# %%
name_titels2[:200]
# Out:
# ['Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="0b45c220-6b85-444e-bac6-dd0b05422c5d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="11247c35-31bf-42a4-bda0-fbba84326a12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="1abdfb9b-bf8e-41c0-95d8-75ca1801a535")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="11179620-0848-4a84-a23f-5230856ab771")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="769df26f-c2de-48d5-a9b4-04720322fd8a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="d06eb8ee-6966-4f84-8eb4-6c54ebf460be")>,
# ...

# %%
price_titels3=[]
for i in titles_tag:
    price_titels3.append(i.text)
price_titels3
# Out:
# ['5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '5,956',
#  '5,956',
#  '6,055',
#  '6,055',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,401',
#  '6,401',
#  '6,401',
#  '6,443',
#  '6,480',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '7,012',
#  '7,012',
#  '7,178',
#  '7,635',
#  '7,908',
#  '8,643',
#  '9,373',
#  '9,373',
#  '10,108',
#  '10,108',
#  '10,500',
#  '10,500',
#  '10,500',
#  '10,947',
#  '12,413',
#  '12,413',
#  '12,939',
#  '12,939',
# ...

# %%
len(price_titels3)
# Out:
# 204

# %%
price_titels3[:200]
# Out:
# ['5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '5,956',
#  '5,956',
#  '6,055',
#  '6,055',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,113',
#  '6,401',
#  '6,401',
#  '6,401',
#  '6,443',
#  '6,480',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '6,690',
#  '7,012',
#  '7,012',
#  '7,178',
#  '7,635',
#  '7,908',
#  '8,643',
#  '9,373',
#  '9,373',
#  '10,108',
#  '10,108',
#  '10,500',
#  '10,500',
#  '10,500',
#  '10,947',
#  '12,413',
#  '12,413',
#  '12,939',
#  '12,939',
# ...

# %%
titles_tag=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
titles_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="8f32a9cc-2be9-4868-8fdb-1e57f6ddf98a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="88ba10cf-d83a-4811-a38d-2a19ddf6683d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="2ed9ad46-ac19-49ea-86c1-d4692a2335dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="3589a739-73a8-4ebd-90e9-4402609de6ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="20108538-1b08-4a5b-9347-a3da7660dc92")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="030a5e546c94b36a8bc569bf82c7c703", element="b0e0fdbc-f1ee-4f4c-ae8f-bc3b6528bd5e")>,
# ...

# %%
price_titels2=[]
for i in titles_tag:
    price_titels2.append(i.text)
price_titels2
# Out:
# ['New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
# ...

# %%
NAME2= []
for i in range(1,len(price_titels2),2):
    NAME2.append(price_titels2[i])
NAME2
# Out:
# ['Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
# ...

# %%
NAME2[:200]
# Out:
# ['Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
# ...

# %%
NAME4= []
for i in range(2,len(price_titels2),2):
    NAME4.append(price_titels2[i])
NAME4
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
NAME4[:200]
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
copy
# Out:
#           Name              id  price arrival time departure time hours taken  \
# 0     Go First         G8-2513  5,954        16:35          18:40      2h 05m
# 1     Go First          G8-173  5,954        08:35          10:45      2h 10m
# 2     SpiceJet         SG-8185  5,954        08:40          10:50      2h 10m
# 3     SpiceJet         SG-8938  5,954        17:45          19:55      2h 10m
# 4     Go First         G8-1171  5,954        12:45          15:00      2h 15m
# ..         ...             ...    ...          ...            ...         ...
# 195   Go First      G8-172/422               15:30
# 196   Go First      G8-174/422               11:15
# 197   Go First     G8-2541/423               19:10
# 198    Vistara  UK-974/819/897               08:15
# 199  Air India      AI-482/542               12:35
#
#     starting point destination
# 0        New Delhi        Pune
# 1        New Delhi        Pune
# 2        New Delhi        Pune
# 3        New Delhi        Pune
# ...

# %%
import pandas as pd
copy=pd.DataFrame({})
copy['Name']=name_titels2[:200]
copy['id']=name_titels[:200]
copy['price']=price_titels3[:200]
copy['arrival time']=sname_titels2[:200]
copy['departure time']=dname_titels2[:200]
copy['hours taken']=name_titels12[:200]
copy['starting point']=NAME4[:200]
copy['destination']=NAME2[:200]

# %%
copy
# Out:
#           Name              id  price arrival time departure time hours taken  \
# 0     Go First         G8-2513  5,954        16:35          18:40      2h 05m
# 1     Go First          G8-173  5,954        08:35          10:45      2h 10m
# 2     SpiceJet         SG-8185  5,954        08:40          10:50      2h 10m
# 3     SpiceJet         SG-8938  5,954        17:45          19:55      2h 10m
# 4     Go First         G8-1171  5,954        12:45          15:00      2h 15m
# ..         ...             ...    ...          ...            ...         ...
# 195   Go First      G8-172/422               15:30
# 196   Go First      G8-174/422               11:15
# 197   Go First     G8-2541/423               19:10
# 198    Vistara  UK-974/819/897               08:15
# 199  Air India      AI-482/542               12:35
#
#     starting point destination
# 0        New Delhi        Pune
# 1        New Delhi        Pune
# 2        New Delhi        Pune
# 3        New Delhi        Pune
# ...

# %%
copy.to_csv('flight1111.csv')
